# %%
pip install pyspellchecker
# Out:
# Requirement already satisfied: pyspellchecker in d:\anaconda\lib\site-packages (0.8.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)

# %%
pip install pdfplumber
# Out:
# Requirement already satisfied: pdfplumber in d:\anaconda\lib\site-packages (0.10.4)
# Requirement already satisfied: pypdfium2>=4.18.0 in d:\anaconda\lib\site-packages (from pdfplumber) (4.27.0)
# Requirement already satisfied: Pillow>=9.1 in d:\anaconda\lib\site-packages (from pdfplumber) (9.4.0)
# Requirement already satisfied: pdfminer.six==20221105 in d:\anaconda\lib\site-packages (from pdfplumber) (20221105)
# Requirement already satisfied: cryptography>=36.0.0 in d:\anaconda\lib\site-packages (from pdfminer.six==20221105->pdfplumber) (39.0.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in d:\anaconda\lib\site-packages (from pdfminer.six==20221105->pdfplumber) (2.0.4)
# Requirement already satisfied: cffi>=1.12 in d:\anaconda\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (1.15.1)
# Requirement already satisfied: pycparser in d:\anaconda\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)

# %%
pip install PyPDF2 nltk spellchecker
# Out:
# Requirement already satisfied: PyPDF2 in d:\anaconda\lib\site-packages (3.0.1)
# Requirement already satisfied: nltk in d:\anaconda\lib\site-packages (3.7)
# Requirement already satisfied: spellchecker in d:\anaconda\lib\site-packages (0.4)
# Requirement already satisfied: tqdm in d:\anaconda\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in d:\anaconda\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: joblib in d:\anaconda\lib\site-packages (from nltk) (1.1.1)
# Requirement already satisfied: click in d:\anaconda\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: setuptools in d:\anaconda\lib\site-packages (from spellchecker) (65.6.3)
# Requirement already satisfied: inexactsearch in d:\anaconda\lib\site-packages (from spellchecker) (1.0.2)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: soundex>=1.0 in d:\anaconda\lib\site-packages (from inexactsearch->spellchecker) (1.1.3)
# Requirement already satisfied: silpa-common>=0.3 in d:\anaconda\lib\site-packages (from inexactsearch->spellchecker) (0.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)

# %%
import re
import pdfplumber
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Define the path for your PDF file and output file
pdf_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl.pdf'
Data_Preprocessing = 'Data Preprocessing.txt'

# Function to preprocess text
def preprocess_text(text):
    # Normalize text
    text = text.lower()
    text = re.sub(r'(?<!\w)([A-Za-z])\s+', r'\1', text)
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'[^\w\s]', '', text)

    # Tokenize text without stemming
    tokens = word_tokenize(text)

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]

    return ' '.join(filtered_tokens)

# Read the PDF file using pdfplumber
def extract_text_from_pdf(pdf_path):
    text_content = []
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text_content.append(page.extract_text())

    return ' '.join(text_content).replace('\n', ' ')

# Extract text from PDF
pdf_text = extract_text_from_pdf(pdf_file_path)

# Preprocess text
preprocessed_text = preprocess_text(pdf_text)

# Write the preprocessed text to a new file
with open(Data_Preprocessing, 'w', encoding='utf-8') as output_file:
    output_file.write(preprocessed_text)

print("Preprocessing complete. Output saved to", Data_Preprocessing)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Preprocessing complete. Output saved to Data Preprocessing.txt

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')

input_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Data Preprocessing.txt'

with open(input_file_path, 'r', encoding='utf-8') as file:
    preprocessed_text = file.read()

sentences = nltk.sent_tokenize(preprocessed_text)

sid = SentimentIntensityAnalyzer()

# Now, let's redefine our sentiment labels more generally:
positive_label = "Positive"
negative_label = "Negative"
neutral_label = "Neutral"

# Function to label sentiment
def label_sentiment(sentence):
    sentiment_score = sid.polarity_scores(sentence)
    compound_score = sentiment_score['compound']

    if compound_score >= 0.2:
        return positive_label
    elif compound_score <= -0.2:
        return negative_label
    else:
        return neutral_label

# Apply sentiment labeling to each sentence
sentiment_labels = [label_sentiment(sentence) for sentence in sentences]

# Count the occurrences of each label
label_counts = {label: sentiment_labels.count(label) for label in set(sentiment_labels)}

# Display the counts for each sentiment label
print("Sentiment Labels and Counts:")
for label, count in label_counts.items():
    print(f"{label}: {count}")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# Sentiment Labels and Counts:
# Optimistic: 1
# Aspirational: 1
# Love: 1
# Curious: 1
# Affectionate: 1
# Gratitude: 1
# Hopeful: 1
# Joy: 1

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')

input_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Data Preprocessing.txt'

with open(input_file_path, 'r', encoding='utf-8') as file:
    preprocessed_text = file.read()

sentences = nltk.sent_tokenize(preprocessed_text)

sid = SentimentIntensityAnalyzer()

# Now, let's redefine our sentiment labels more generally:
positive_label = "Positive"
negative_label = "Negative"
neutral_label = "Neutral"

# Function to label sentiment
def label_sentiment(sentence):
    sentiment_score = sid.polarity_scores(sentence)
    compound_score = sentiment_score['compound']

    if compound_score >= 0.2:
        return positive_label
    elif compound_score <= -0.2:
        return negative_label
    else:
        return neutral_label

# Apply sentiment labeling to each sentence
sentiment_labels = [label_sentiment(sentence) for sentence in sentences]

# Count the occurrences of each label
label_counts = {label: sentiment_labels.count(label) for label in set(sentiment_labels)}

# Display the counts for each sentiment label
print("Sentiment Labels and Counts:")
for label, count in label_counts.items():
    print(f"{label}: {count}")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Sentiment Labels and Counts:
# Positive: 1

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')
nltk.download('punkt')

input_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Data Preprocessing.txt'

with open(input_file_path, 'r', encoding='utf-8') as file:
    text = file.read()

sentences = nltk.sent_tokenize(text)
sid = SentimentIntensityAnalyzer()

# Define a function to determine the custom sentiment label
def custom_label(sentence):
    score = sid.polarity_scores(sentence)
    words = nltk.word_tokenize(sentence.lower())

    # Example of custom logic based on keywords and baseline sentiment:
    # This is a simplified version. You might need more complex rules.
    if score['compound'] > 0.2:
        if any(word in words for word in ['hope', 'dream']):
            return 'Hopeful'
        elif any(word in words for word in ['curious']):
            return 'Curious'
        # Add rules for other positive sentiments as needed.
    elif score['compound'] < -0.2:
        if any(word in words for word in ['fear', 'threat']):
            return 'Fearful'
        elif any(word in words for word in ['frustrated', 'confined']):
            return 'Frustrated'
        # Add rules for other negative sentiments as needed.
    else:
        if any(word in words for word in ['reflect', 'self']):
            return 'Reflective'
        elif any(word in words for word in ['grow', 'mature']):
            return 'Maturing'
        # Add rules for other complex sentiments as needed.
    
    return 'Neutral'  # Default label if no other rules apply

# Apply the custom labeling function to each sentence
custom_labels = [custom_label(sentence) for sentence in sentences]

# Count the occurrences of each label
label_counts = {label: custom_labels.count(label) for label in set(custom_labels)}

# Print the results
print("Custom Sentiment Labels and Counts:")
for label, count in label_counts.items():
    print(f"{label}: {count}")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Custom Sentiment Labels and Counts:
# Hopeful: 1

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('vader_lexicon')
nltk.download('punkt')

# Read text data from your file
input_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Data Preprocessing.txt'
with open(input_file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# Tokenize sentences
sentences = sent_tokenize(text)

# Initialize the VADER sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Define a function to determine the custom sentiment label
def custom_label(sentence):
    score = sid.polarity_scores(sentence)
    words = word_tokenize(sentence.lower())

    # Example of custom logic based on keywords and baseline sentiment:
    if score['compound'] > 0.2:
        if any(word in words for word in ['hope', 'dream']):
            return 'Hopeful'
        elif any(word in words for word in ['curious']):
            return 'Curious'
        # Add rules for other positive sentiments as needed.
    elif score['compound'] < -0.2:
        if any(word in words for word in ['fear', 'threat']):
            return 'Fearful'
        elif any(word in words for word in ['frustrated', 'confined']):
            return 'Frustrated'
        # Add rules for other negative sentiments as needed.
    else:
        if any(word in words for word in ['reflect', 'self']):
            return 'Reflective'
        elif any(word in words for word in ['grow', 'mature']):
            return 'Maturing'
        # Add rules for other complex sentiments as needed.

    return 'Neutral'  # Default label if no other rules apply

# Apply the custom labeling function to each sentence
custom_labels = [custom_label(sentence) for sentence in sentences]

# Count the occurrences of each label
label_counts = {label: custom_labels.count(label) for label in set(custom_labels)}

# Print the custom sentiment labels and their counts
for label, count in label_counts.items():
    print(f"{label}: {count}")

# You can further process or analyze the labeled data as needed
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Hopeful: 1

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('vader_lexicon')
nltk.download('punkt')

# Read text data from your file
input_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Data Preprocessing.txt'
with open(input_file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# Tokenize sentences
sentences = sent_tokenize(text)

# Initialize the VADER sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Define a function to determine the custom sentiment label
def custom_label(sentence):
    score = sid.polarity_scores(sentence)
    words = word_tokenize(sentence.lower())

    # Custom logic based on keywords and sentiment scores:
    if score['compound'] > 0.2:
        if any(word in words for word in ['hope', 'dream']):
            return 'Hopeful'
        elif any(word in words for word in ['curious']):
            return 'Curious'
        # Add rules for other positive sentiments as needed.
    elif score['compound'] < -0.2:
        if any(word in words for word in ['fear', 'threat']):
            return 'Fearful'
        elif any(word in words for word in ['frustrated', 'confined']):
            return 'Frustrated'
        # Add rules for other negative sentiments as needed.
    else:
        if any(word in words for word in ['reflect', 'self']):
            return 'Reflective'
        elif any(word in words for word in ['grow', 'mature']):
            return 'Maturing'
        # Add rules for other complex sentiments as needed.

    return 'Neutral'  # Default label if no other rules apply

# Apply the custom labeling function to each sentence
custom_labels = [custom_label(sentence) for sentence in sentences]

# Count the occurrences of each label
label_counts = {label: custom_labels.count(label) for label in set(custom_labels)}

for label, count in label_counts.items():
    print(f"{label}: {count}")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Hopeful: 1

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('vader_lexicon')
nltk.download('punkt')

# Read text data from your file
input_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Data Preprocessing.txt'
with open(input_file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# Tokenize sentences
sentences = sent_tokenize(text)

# Initialize the VADER sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Define a function to determine the custom sentiment label
def custom_label(sentence):
    score = sid.polarity_scores(sentence)

    # Custom logic based on sentiment scores:
    if score['compound'] > 0.2:
        return 'Positive'
    elif score['compound'] < -0.2:
        return 'Negative'
    else:
        return 'Neutral'

# Apply the custom labeling function to each sentence
custom_labels = [custom_label(sentence) for sentence in sentences]

# Count the occurrences of each label
label_counts = {label: custom_labels.count(label) for label in set(custom_labels)}

for label, count in label_counts.items():
    print(f"{label}: {count}")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Positive: 1

# %%
from textblob import TextBlob
import nltk
nltk.download('punkt')

# Define the sentiments
positive_sentiments = ['hopeful', 'curious', 'affectionate', 'optimistic', 'aspirational', 'love', 'joy', 'gratitude']
negative_sentiments = ['fearful', 'frustrated', 'lonely', 'anguish', 'melancholic']
complex_sentiments = ['reflective', 'resilient', 'maturing', 'philosophical', 'conflict']

# Read the text file
with open(r'C:\Users\DELL\Desktop\Project\Untitled Folder\Data Preprocessing.txt') as file:
    text = file.read()

# Tokenize the text into sentences
sentences = nltk.sent_tokenize(text)

# Analyze each sentence
for sentence in sentences:
    blob = TextBlob(sentence)
    polarity = blob.sentiment.polarity

    # Label the sentiment
    if polarity > 0:
        sentiment = 'positive'
    elif polarity < 0:
        sentiment = 'negative'
    else:
        sentiment = 'complex'

    print(f'Sentence: {sentence}\nSentiment: {sentiment}\n')
# Out:
#   Cell In[3], line 1
#     pip install textblob
#         ^
# SyntaxError: invalid syntax

# %%
pip install textblob
# Out:
# Collecting textblobNote: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
#   Downloading textblob-0.18.0.post0-py3-none-any.whl (626 kB)
#      -------------------------------------- 626.3/626.3 kB 4.9 MB/s eta 0:00:00
# Collecting nltk>=3.8
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: click in d:\anaconda\lib\site-packages (from nltk>=3.8->textblob) (8.0.4)
# Requirement already satisfied: joblib in d:\anaconda\lib\site-packages (from nltk>=3.8->textblob) (1.1.1)
# Requirement already satisfied: regex>=2021.8.3 in d:\anaconda\lib\site-packages (from nltk>=3.8->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in d:\anaconda\lib\site-packages (from nltk>=3.8->textblob) (4.64.1)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.6)
# Installing collected packages: nltk, textblob
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.7
#     Uninstalling nltk-3.7:
#       Successfully uninstalled nltk-3.7
# Successfully installed nltk-3.8.1 textblob-0.18.0.post0

# %%
from textblob import TextBlob
import nltk
nltk.download('punkt')

# Define the sentiments
positive_sentiments = ['hopeful', 'curious', 'affectionate', 'optimistic', 'aspirational', 'love', 'joy', 'gratitude']
negative_sentiments = ['fearful', 'frustrated', 'lonely', 'anguish', 'melancholic']
complex_sentiments = ['reflective', 'resilient', 'maturing', 'philosophical', 'conflict']

# Read the text file
with open(r'C:\Users\DELL\Desktop\Project\Untitled Folder\Data Preprocessing.txt') as file:
    text = file.read()

# Tokenize the text into sentences
sentences = nltk.sent_tokenize(text)

# Analyze each sentence
for sentence in sentences:
    blob = TextBlob(sentence)
    polarity = blob.sentiment.polarity
    print(f'Sentence: {sentence}\nPolarity: {polarity}\n')


    # Label the sentiment
    if polarity > 0.1:
        sentiment = 'positive'
    elif polarity < -0.1:
        sentiment = 'negative'
    else:
        sentiment = 'complex'

    print(f'Sentence: {sentence}\nSentiment: {sentiment}\n')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#
ditions facing hunger everpresent threat discovery death complete estrangement outside world boredom petty misunderstandings frustrations living unbearable strain confined quarters atimely story rediscovered new generation diary ayoung girl stands without peer young readers adults continues bring life young woman atime survived worst horror modern world seen remained triumphantly heartbreakingly human throughout ordeal know love anne frank definitive edition achance discover anew readers yet encountered edition cherish anne frank born june died imprisoned bergenbelsen three months short sixteenth birthday otto h frank member immediate framily survive holocaust died mirjam pressler apopular writer books young adults lives germany translated susan massotty foreword anne frank kept adiary june august initially wrote strictly one day gerrit bolkestein amember dutch government exile announced aradio broadcast london war hoped collect eyewitness accounts suffering dutch people german occupation could made available public example specifically mentioned letters diaries impressed speech anne frank decided war would publish abook based diary began rewriting editing diary improving text omitting passages didntthink interesting enough adding others memory time kept original diary scholarly work diary anne frank critical edition annesfirst unedited diary referred version distinguish second edited diary known version b last entry annesdiary dated august august eight people hiding secret annex arrested miep gies bep voskuijl two secretaries working building found annesdiaries strewn allover floor miep gies tucked away adesk drawer safekeeping war became clear anne dead gave diaries unread annesfather otto frank long deliberation otto frank decided fulfill daughterswish publish diary selected material versions aand b editing ashorter version later referred version c readers world know diary afauna girl making choice otto frank bear several points mind begin book kept short would fit aseries put dutch publisher addition several passages dealing annessexuality omitted time diarysinitial publication customary write openly sex certainly books young adults respect dead otto frank also omitted anumber unflattering passages wife residents secret annex anne frank thirteen began diary fifteen forced stop wrote without reserve likes dislikes otto frank died willed daughtersmanuscripts netherlands state institute war documentation amsterdam authenticity diary challenged ever since publication institute war documentation ordered athorough investigation diary proved beyond ashadow adoubt genuine published entirety along results exhaustive study critical edition contains versions band c also articles background frank family circumstances surrounding arrest deportation examination anneshandwriting document materials used anne frankfonds anne frank foundation basel switzerland otto frankssole heir also inherited daughterscopyrights decided anew expanded edition diary published general readers new edition way aff ...
# Sentiment: complex

# %%
from textblob import TextBlob
import nltk
from nltk.tokenize import sent_tokenize

# Download NLTK data for tokenization
nltk.download('punkt')

# Define the sentiments
positive_sentiments = ['hopeful', 'curious', 'affectionate', 'optimistic', 'aspirational', 'love', 'joy', 'gratitude']
negative_sentiments = ['fearful', 'frustrated', 'lonely', 'anguish', 'melancholic']
complex_sentiments = ['reflective', 'resilient', 'maturing', 'philosophical', 'conflict']

# Read the text file
with open(r'C:\Users\DELL\Desktop\Project\Untitled Folder\Data Preprocessing.txt') as file:
    text = file.read()

# Tokenize the text into sentences
sentences = sent_tokenize(text)

# Initialize sentiment counts
sentiment_counts = {label: 0 for label in positive_sentiments + negative_sentiments + complex_sentiments + ['complex']}

# Analyze each sentence
for sentence in sentences:
    blob = TextBlob(sentence)
    polarity = blob.sentiment.polarity

    # Label the sentiment
    if polarity > 2:
        sentiment = 'positive'
    elif polarity < -2:
        sentiment = 'negative'
    else:
        sentiment = 'complex'

    # Increment the corresponding sentiment count
    sentiment_counts[sentiment] += 1

# Display the counts for each sentiment label
print("Sentiment Labels and Counts:")
for label, count in sentiment_counts.items():
    print(f"{label.capitalize()}: {count}")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Sentiment Labels and Counts:
# Hopeful: 0
# Curious: 0
# Affectionate: 0
# Optimistic: 0
# Aspirational: 0
# Love: 0
# Joy: 0
# Gratitude: 0
# Fearful: 0
# Frustrated: 0
# Lonely: 0
# Anguish: 0
# Melancholic: 0
# Reflective: 0
# Resilient: 0
# Maturing: 0
# Philosophical: 0
# Conflict: 0
# Complex: 1

# %%
import re
import pdfplumber
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Define the path for your PDF file and output file
pdf_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl.pdf'
Data_Preprocessing = 'Data Preprocessing.txt'

# Function to preprocess text
def preprocess_text(text):
    # Normalize text
    text = text.lower()
    text = re.sub(r'(?<!\w)([A-Za-z])\s+', r'\1', text)
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'[^\w\s\d]', '', text)

    # Tokenize text without stemming
    tokens = word_tokenize(text)

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]

    return ' '.join(filtered_tokens)

# Read the PDF file using pdfplumber
def extract_text_from_pdf(pdf_path):
    text_content = []
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text_content.append(page.extract_text())

    return ' '.join(text_content).replace('\n', ' ')

# Extract text from PDF
pdf_text = extract_text_from_pdf(pdf_file_path)

# Preprocess text
preprocessed_text = preprocess_text(pdf_text)

# Write the preprocessed text to a new file
with open(Data_Preprocessing, 'w', encoding='utf-8') as output_file:
    output_file.write(preprocessed_text)

print("Preprocessing complete. Output saved to", Data_Preprocessing)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Preprocessing complete. Output saved to Data Preprocessing.txt

# %%
pip install datefinder
# Out:
# Requirement already satisfied: datefinder in d:\anaconda\lib\site-packages (0.7.3)
# Requirement already satisfied: python-dateutil>=2.4.2 in d:\anaconda\lib\site-packages (from datefinder) (2.8.2)
# Requirement already satisfied: pytz in d:\anaconda\lib\site-packages (from datefinder) (2022.7)
# Requirement already satisfied: regex>=2017.02.08 in d:\anaconda\lib\site-packages (from datefinder) (2022.7.9)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.4.2->datefinder) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)

# %%
import re
import pdfplumber
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from docx import Document
import datefinder

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Function to add a newline before and after each date in the text
def insert_newlines(text):
    # Find all date-like patterns using datefinder
    matches = datefinder.find_dates(text)

    # Add newlines before and after each date-like pattern
    for match in reversed(list(matches)):
        date_str = match.strftime("%A, %B %d, %Y")
        text = text.replace(date_str, f'\n{date_str}\n')

    # Define a regex pattern for other date formats
    date_pattern = re.compile(
        r'\b(?:Monday|Tuesday|Wednesday|Thursday|Friday|Saturday|Sunday), '
        r'(?:January|February|March|April|May|June|July|August|September|October|November|December) '
        r'\d{1,2}, \d{4}\b'
    )
    
    # Add newlines before and after each match in the regex pattern
    text = date_pattern.sub(r'\n\g<0>\n', text)

    return text

# Function to preprocess text
def preprocess_text(text):
    # Normalize text
    text = text.lower()
    text = re.sub(r'(?<!\w)([A-Za-z])\s+', r'\1', text)
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'[^\w\s\d]', '', text)

    # Tokenize text without stemming
    tokens = word_tokenize(text)

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]

    return ' '.join(filtered_tokens)

# Read the PDF file using pdfplumber
def extract_text_from_pdf(pdf_path):
    text_content = []
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text_content.append(page.extract_text())

    return ' '.join(text_content).replace('\n', ' ')

# Define the path for your PDF file and output file
pdf_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl.pdf'
output_word_file = 'OutputDocument.docx'

# Extract text from PDF
pdf_text = extract_text_from_pdf(pdf_file_path)

# Add newlines before and after dates
pdf_text_with_newlines = insert_newlines(pdf_text)

# Now preprocess text excluding the dates
# Split the text by newlines, preprocess non-date lines, and rejoin the text
processed_lines = [preprocess_text(line) for line in pdf_text_with_newlines.split('\n')]
preprocessed_text = '\n'.join(processed_lines)

# Create a Word document
doc = Document()
doc.add_paragraph(preprocessed_text)

# Save the Word document
doc.save(output_word_file)

print("Preprocessing complete. Output saved to", output_word_file)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Preprocessing complete. Output saved to OutputDocument.docx

# %%
import re
import pdfplumber
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from docx import Document

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Define a regex pattern for the date format
date_pattern = re.compile(r'(?:[A-Za-z]+, [A-Za-z]+ \d{1,2}, \d{4})')

# Function to insert newlines before and after each date in the text
def insert_newlines(text):
    # Add newlines before and after each date match
    text_with_newlines = date_pattern.sub(r':\n\n\n\g<0>:\n', text)
    return text_with_newlines

# Function to preprocess text
def preprocess_text(text):
    # Normalize text
    text = text.lower()
    text = re.sub(r'(?<!\w)([A-Za-z])\s+', r'\1', text)
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'[^\w\s\d]', '', text)

    # Tokenize text without stemming
    tokens = word_tokenize(text)

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]

    return ' '.join(filtered_tokens)

# Read the PDF file using pdfplumber
def extract_text_from_pdf(pdf_path):
    text_content = []
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text_content.append(page.extract_text())

    return ' '.join(text_content).replace('\n', ' ')

# Define the path for your PDF file and output file
pdf_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl.pdf'
output_word_file = 'Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'

# Extract text from PDF
pdf_text = extract_text_from_pdf(pdf_file_path)

# Add newlines before and after dates
pdf_text_with_newlines = insert_newlines(pdf_text)

# Now preprocess text excluding the dates
# Split the text by newlines, preprocess non-date lines, and rejoin the text
processed_lines = [preprocess_text(line) for line in pdf_text_with_newlines.split('\n')]
preprocessed_text = '\n'.join(processed_lines)

# Create a Word document
doc = Document()
doc.add_paragraph(preprocessed_text)

# Save the Word document
doc.save(output_word_file)

print("Preprocessing complete. Output saved to", output_word_file)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Preprocessing complete. Output saved to Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx

# %%
import docx
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Step 1: Preprocess the Text
diary_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'  # Replace with the path to your Word document

# Read the diary text from the document
doc = docx.Document(diary_file_path)
diary_text = " ".join([paragraph.text for paragraph in doc.paragraphs])

# Tokenize and preprocess the text
stop_words = set(stopwords.words('english'))
tokens = word_tokenize(diary_text.lower())
preprocessed_tokens = [token for token in tokens if token.isalpha() and token not in stop_words]

# Step 2: Load the NRC Emotion Lexicon
nrc_lexicon = nltk.corpus.emotion.NRC_EmotionLexicon()

# Step 3: Match Words with Emotion Lexicon and Assign Sentiment Labels
sentiments = {'positive': 0, 'negative': 0, 'neutral': 0}
emotions = {'joy': 0, 'sadness': 0, 'anger': 0, 'fear': 0, 'trust': 0, 'disgust': 0, 'surprise': 0, 'anticipation': 0,
            'excitement': 0, 'contentment': 0}

for word in preprocessed_tokens:
    if word in nrc_lexicon.word_index.keys():
        emotions_found = nrc_lexicon.word_index[word]
        for emotion, sentiment in emotions_found.items():
            if sentiment == 1:
                sentiments['positive'] += 1
                if emotion in emotions:
                    emotions[emotion] += 1
            elif sentiment == -1:
                sentiments['negative'] += 1
                if emotion in emotions:
                    emotions[emotion] += 1
            else:
                sentiments['neutral'] += 1

# Step 4: Print Sentiment Analysis Results
print("Sentiment Analysis Results:")
print("Positive: ", sentiments['positive'])
print("Negative: ", sentiments['negative'])
print("Neutral: ", sentiments['neutral'])
print("Emotions: ", emotions)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 19
#      16 preprocessed_tokens = [token for token in tokens if token.isalpha() and token not in stop_words]
#      18 # Step 2: Load the NRC Emotion Lexicon
# ---> 19 nrc_lexicon = nltk.corpus.emotion.NRC_EmotionLexicon()
#      21 # Step 3: Match Words with Emotion Lexicon and Assign Sentiment Labels
#      22 sentiments = {'positive': 0, 'negative': 0, 'neutral': 0}
#
# File D:\Anaconda\lib\site-packages\nltk\lazyimport.py:121, in LazyModule.__getattr__(self, name)
#     116     print(
#     117         "LazyModule: "
#     118         "Module load triggered by attribute %r read access" % name
#     119     )
#     120 module = self.__lazymodule_import()
# --> 121 return getattr(module, name)
#
# AttributeError: module 'nltk.corpus' has no attribute 'emotion'

# %%
pip install python-docx
# Out:
# Requirement already satisfied: python-docx in d:\anaconda\lib\site-packages (1.1.0)Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# Requirement already satisfied: typing-extensions in d:\anaconda\lib\site-packages (from python-docx) (4.4.0)
# Requirement already satisfied: lxml>=3.1.0 in d:\anaconda\lib\site-packages (from python-docx) (4.9.1)

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Step 1: Preprocess the Text
diary_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'  # Replace with the path to your Word document

# Read the diary text from the document
doc = docx.Document(diary_file_path)
diary_text = " ".join([paragraph.text for paragraph in doc.paragraphs])

# Tokenize and preprocess the text
stop_words = set(stopwords.words('english'))
tokens = word_tokenize(diary_text.lower())
preprocessed_tokens = [token for token in tokens if token.isalpha() and token not in stop_words]

# Step 2: Load the NRC Emotion Lexicon
nrc_lexicon_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\NRC-emotion-lexicon-wordlevel-alphabetized-v0.92.txt'  # Replace with the path to your downloaded lexicon

# Create a dictionary to store the emotion mappings
nrc_lexicon = {}
with open(nrc_lexicon_path, "r") as file:
    for line in file:
        word, emotion, value = line.strip().split("\t")
        if word in nrc_lexicon:
            nrc_lexicon[word][emotion] = int(value)
        else:
            nrc_lexicon[word] = {emotion: int(value)}

# Step 3: Match Words with Emotion Lexicon and Assign Sentiment Labels
sentiments = {'positive': 0, 'negative': 0, 'neutral': 0}
emotions = {'joy': 0, 'sadness': 0, 'anger': 0, 'fear': 0, 'trust': 0, 'disgust': 0, 'surprise': 0, 'anticipation': 0,
            'excitement': 0, 'contentment': 0}

for word in preprocessed_tokens:
    if word in nrc_lexicon:
        emotions_found = nrc_lexicon[word]
        for emotion, sentiment in emotions_found.items():
            if sentiment == 1:
                sentiments['positive'] += 1
                if emotion in emotions:
                    emotions[emotion] += 1
            elif sentiment == -1:
                sentiments['negative'] += 1
                if emotion in emotions:
                    emotions[emotion] += 1
            else:
                sentiments['neutral'] += 1

# Step 4: Print Sentiment Analysis Results
print("Sentiment Analysis Results:")
print("Positive: ", sentiments['positive'])
print("Negative: ", sentiments['negative'])
print("Neutral: ", sentiments['neutral'])
print("Emotions: ", emotions)
# Out:
# Sentiment Analysis Results:
# Positive:  20236
# Negative:  0
# Neutral:  167334
# Emotions:  {'joy': 1932, 'sadness': 1704, 'anger': 1276, 'fear': 1624, 'trust': 2528, 'disgust': 976, 'surprise': 966, 'anticipation': 2159, 'excitement': 0, 'contentment': 0}

# %%
import docx
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Step 1: Preprocess the Text
diary_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'  # Replace with the path to your Word document

# Read the diary text from the document
doc = docx.Document(diary_file_path)
diary_text = " ".join([paragraph.text for paragraph in doc.paragraphs])

# Tokenize and preprocess the text
stop_words = set(stopwords.words('english'))
tokens = word_tokenize(diary_text.lower())
preprocessed_tokens = [token for token in tokens if token.isalpha() and token not in stop_words]

# Step 2: Load the NRC Emotion Lexicon
nrc_lexicon_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\NRC-emotion-lexicon-wordlevel-alphabetized-v0.92.txt'  # Replace with the path to your downloaded lexicon

# Create a dictionary to store the emotion mappings
nrc_lexicon = {}
with open(nrc_lexicon_path, "r") as file:
    for line in file:
        word, emotion, value = line.strip().split("\t")
        if word in nrc_lexicon:
            nrc_lexicon[word][emotion] = int(value)
        else:
            nrc_lexicon[word] = {emotion: int(value)}

# Step 3: Match Words with Emotion Lexicon and Assign Sentiment Labels
sentiments = {'positive': 0, 'negative': 0, 'neutral': 0}
emotions = {'joy': 0, 'sadness': 0, 'anger': 0, 'fear': 0, 'trust': 0, 'disgust': 0, 'surprise': 0, 'anticipation': 0,
            'excitement': 0, 'contentment': 0}

words_with_emotions = {}  # Store words with their corresponding emotions

for word in preprocessed_tokens:
    if word in nrc_lexicon:
        emotions_found = nrc_lexicon[word]
        for emotion, sentiment in emotions_found.items():
            if sentiment == 1:
                sentiments['positive'] += 1
                if emotion in emotions:
                    emotions[emotion] += 1
            elif sentiment == -1:
                sentiments['negative'] += 1
                if emotion in emotions:
                    emotions[emotion] += 1
            else:
                sentiments['neutral'] += 1
            if word in words_with_emotions:
                words_with_emotions[word].append(emotion)
            else:
                words_with_emotions[word] = [emotion]

# Step 4: Print Sentiment Analysis Results
print("Sentiment Analysis Results:")
print("Positive: ", sentiments['positive'])
print("Negative: ", sentiments['negative'])
print("Neutral: ", sentiments['neutral'])
print("Emotions: ", emotions)

# Print words with their corresponding emotions
print("\nWords with Emotions:")
for word, emotion_list in words_with_emotions.items():
    print(word + ": " + ", ".join(emotion_list))
# Out:
# Sentiment Analysis Results:
# Positive:  20236
# Negative:  0
# Neutral:  167334
# Emotions:  {'joy': 1932, 'sadness': 1704, 'anger': 1276, 'fear': 1624, 'trust': 2528, 'disgust': 976, 'surprise': 966, 'anticipation': 2159, 'excitement': 0, 'contentment': 0}
#
# Words with Emotions:
# diary: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# girl: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# definitive: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# edition: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# frank: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise ...
# otto: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# book: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, ...
# flap: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# twentieth: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# century: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# publication: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# read: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, ...
# people: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surpris ...
# world: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise ...
# remains: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# testament: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# nature: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# human: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# spirit: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# omitted: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# constitute: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# material: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# reinforce: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# fact: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# symbol: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# sexuality: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# young: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# found: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# disagreement: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# mother: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surpris ...
# sorrow: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# adult: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# ...
# bracelet: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# album: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# gale: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# gauge: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# idle: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# liberate: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# abject: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# rightful: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# weakened: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# treaty: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# scoff: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# conceited: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# arrogant: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# chief: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# ailment: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# curse: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# refrain: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# buried: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# tolerant: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# easygoing: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# access: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# accused: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# contemplative: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# smitten: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# moonlight: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# holiday: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# glare: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# spellbound: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# starry: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# isolated: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# humble: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# dusty: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# earn: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# equal: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# respected: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# esteem: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# fame: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# childbirth: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# commonly: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# hero: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# birth: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# con: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# race: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# imply: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# system: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# society: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# inevitable: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# unavoidable: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# pompous: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# suicide: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# sufficiently: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# specimen: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# yon: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# museum: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# cam: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# equipment: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# captive: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# weapon: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# leader: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# socialist: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# enlist: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# pig: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# wonderfully: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# triumphant: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# ghastly: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# painful: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# buddy: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# innkeeper: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# artistic: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# weakness: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# admirable: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# deceit: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# lean: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# sea: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# effective: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# antidote: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# inviting: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# satisfaction: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# blessed: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# ability: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# purgatory: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# review: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# accomplish: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# produce: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# auction: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# bucket: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# mail: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# hurried: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# halfway: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# racket: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# enamel: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# meticulous: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# pod: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# string: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# worm: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# morn: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# monotony: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# killing: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# occupy: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# outstanding: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# obvious: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# length: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# biased: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# bearing: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# footing: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# criticism: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# guilt: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# intimacy: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# expand: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# afar: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# impact: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# crushed: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# cruelty: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# assassination: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# divine: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# providence: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust, anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# conspiracy: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# establish: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# dictatorship: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# impeccable: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# announce: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# personnel: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# soldier: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# shoot: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# commanding: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# rifle: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# reprimand: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# logical: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# previous: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# contradiction: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# cheerfulness: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# embrace: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# ambush: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# diversion: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# interlude: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# powerful: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# gout: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# sergeant: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# uniform: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# civilian: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# imprisonment: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# transit: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# transport: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# testimony: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# shortly: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# chambers: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# epidemic: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# translation: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# educational: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
# international: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, tr
for word in preprocessed_tokens:
    if word in nrc_lexicon:
        emotions_found = nrc_lexicon[word]
        for emotion, sentiment in emotions_found.items():
            if sentiment == 1 and emotion in emotions:
                emotions[emotion].add(word)
                sentiment_score += sentiment

# Step 4: Print Emotions, Counts, Distinct Words, and Sentiment Scores
print("Emotions:")
for emotion, words in emotions.items():
    count = len(words)
    distinct_words = ", ".join(words)
    emotion_sentiment_score = sum([nrc_lexicon[word][emotion] for word in words])
    print(f"\n{emotion.capitalize()} (Count: {count}): {distinct_words}")
    print(f"Sentiment Score: {emotion_sentiment_score}")

print("\nCombined Sentiment Score:", sentiment_score)
# Out:
# Emotions:
#
# Joy (Count: 275): darling, approve, clown, unexpected, remarkable, peaceful, cheer, rising, humanity, merry, esteem, pay, save, glow, devout, lucky, dance, intimate, lovely, teach, entertaining, faith, candid, romance, volunteer, salvation, abundance, welcomed, brighten, remedy, triumph, garden, accomplished, joy, perfection, heroism, sun, gift, companion, rescue, friendliness, triumphant, wonderful, miracle, fun, laughing, white, honest, excellent, celebrated, comfort, amusement, reconciliation, bloom, reward, classics, friend, true, engaged, blessed, mother, doll, art, liking, amused, weight, ribbon, embrace, share, entertainment, kiss, yearning, vivid, feeling, affection, picnic, present, liberate, youth, favorite, compensate, money, found, flirt, beautiful, special, graduation, pray, finally, compliment, bliss, succeed, green, treasure, childhood, flattering, safe, possess, marriage, marry, luck, content, baby, treat, wonderfully, labor, cheerfulness, sympathetic, amusing, magnificent, god, happiness, praised, luxury, exquisite, shining, respect, promise, advance, humorous, freely, food, amazingly, starry, buddy, liberation, nap, celebration, holiday, victory, exuberance, hero, excited, enlighten, progress, gain, helpful, shopping, majority, raving, sex, chocolate, bouquet, admirable, elegant, prestige, friendly, intense, splendid, friendship, victor, spirits, sweetheart, thankful, improve, overjoyed, entertained, hilarity, ceremony, birthday, dawn, smile, civilized, adorable, organ, lover, brilliant, glad, accomplish, happy, fulfill, passion, cheerful, pleased, peace, emancipation, silly, hopeful, sweet, prosperous, tenderness, passionate, daughter, tree, success, sunshine, score, cash, inseparable, deal, generous, admiration, beer, young, heavenly, laughter, adore, praise, delicious, hobby, grin, good, jump, delighted, grow, thrilling, eager, angel, cream, tickle, star, enjoy, powerful, vacation, delight, music, receiving, ecstasy, glee, champion, confidence, pride, giggle, optimism, exciting, destination, clean, truce, outstanding, electric, amuse, fancy, splendor, pretty, oasis, beam, satisfied, kind, entertain, delightful, achieve, nursery, proud, enjoying, surprise, heroic, loving, pleasant, swim, inviting, sing, glory, gorgeous, paragon, saintly, child, tender, cherish, alive, hope, beauty, love, appreciation, laugh, witty, freedom, goodness, excitement, perfect, loyal, birth, spouse, charmed, diary, smiling
# Sentiment Score: 275
#
# Sadness (Count: 348): neglected, shortage, lovely, woe, sunk, wretched, fuss, homicide, hurt, dashed, dislocated, tease, late, inferior, disaster, dismal, moan, unhappy, dismay, mug, explode, malaria, wanting, suffocating, unkind, suffering, stroke, victim, sympathy, grief, abandoned, miserable, unrequited, unhealthy, unfair, orphan, bloody, worn, spinster, humbled, dictatorship, withdraw, forbid, frayed, sick, bad, penalty, kill, sorrow, gloomy, darkness, bang, impossible, curse, ruined, resigned, criticize, remove, unhappiness, despair, necessity, abandon, disagreement, shattered, collapse, hopeless, struggle, blunder, illness, grumpy, torment, broke, bitterly, difficulty, insult, dis
ager, angel, cream, tickle, star, enjoy, plan, develop, lesson, vacation, delight, receiving, warned, powerful, ecstasy, mediate, hunting, grim, champion, anxious, forming, exciting, optimism, destination, stripped, track, expect, announcement, fancy, splendor, pretty, anxiety, errand, diagnosis, oasis, owing, delightful, investigation, proud, enjoying, correspondence, theory, pleasant, swim, inviting, sing, glory, importance, paragon, linger, saintly, public, child, cherish, alive, hope, gradual, epidemic, hurried, goodness, excitement, perfect, birth, kiss, dreadful, wont
# Sentiment Score: 288
#
# Excitement (Count: 0):
# Sentiment Score: 0
#
# Combined Sentiment Score: 13165

# %%
import pandas as pd
import docx
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.sentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import nltk
nltk.download('all')
# Step 1: Preprocess the Text
diary_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'  # Replace with the path to your Word document

# Read the diary text from the document
doc = docx.Document(diary_file_path)
diary_text = " ".join([paragraph.text for paragraph in doc.paragraphs])

# Tokenize and preprocess the text
stop_words = set(stopwords.words('english'))
tokens = word_tokenize(diary_text.lower())
preprocessed_tokens = [token for token in tokens if token.isalpha() and token not in stop_words]

# Step 2: Load the Emotion Lexicon
nrc_lexicon_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\NRC-emotion-lexicon-wordlevel-alphabetized-v0.92.txt'  # Replace with the path to your downloaded lexicon

# Create a dictionary to store the emotion mappings
nrc_lexicon = {}
with open(nrc_lexicon_path, "r") as file:
    for line in file:
        word, emotion, value = line.strip().split("\t")
        if word in nrc_lexicon:
            nrc_lexicon[word][emotion] = int(value)
        else:
            nrc_lexicon[word] = {emotion: int(value)}

# Step 3: Perform Temporal Sentiment Analysis
sentiment_analyzer = SentimentIntensityAnalyzer()

# Read the diary entries from the dataset
diary_entries_path =  r'C:\Users\DELL\Desktop\Project\Untitled Folder\Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'  # Replace with the path to your dataset
with open(diary_entries_path, 'r') as file:
    lines = file.readlines()

dates = []
entries = []

# Extract dates and entries from the lines
for line in lines:
    line = line.strip()
    if line:
        date, entry = line.split(':')
        dates.append(date.strip())
        entries.append(entry.strip())

# Create a DataFrame with dates and entries
df = pd.DataFrame({'Date': dates, 'Text': entries})

# Group entries by date
grouped_entries = df.groupby('Date')['Text'].apply(list)

# Create empty dictionaries to store emotion scores for each date
emotion_scores = {emotion: [] for emotion in nrc_lexicon['happy'].keys()}

# Calculate emotion scores for each date
for date, entries in grouped_entries.items():
    sentiment_scores = {emotion: 0 for emotion in nrc_lexicon['happy'].keys()}
    for entry in entries:
        tokens = word_tokenize(entry.lower())
        preprocessed_tokens = [token for token in tokens if token.isalpha() and token not in stop_words]
        for token in preprocessed_tokens:
            if token in nrc_lexicon:
                emotions_found = nrc_lexicon[token]
                for emotion, sentiment in emotions_found.items():
                    sentiment_scores[emotion] += sentiment

    for emotion, score in sentiment_scores.items():
        emotion_scores[emotion].append(score)

# Step 4: Visualize the Emotion Journey
plt.figure(figsize=(12, 6))
for emotion, scores in emotion_scores.items():
    plt.plot(pd.to_datetime(df['Date'].unique()), scores, label=emotion.capitalize())

plt.xlabel('Date')
plt.ylabel('Emotion Score')
plt.title('Emotion Journey over Time')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\book_grammars.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown.zip.
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\city_database.zip.
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gazetteers.zip.
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\genesis.zip.
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gutenberg.zip.
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ieer.zip.
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\inaugural.zip.
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\indian.zip.
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\kimmo.zip.
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\mac_morpho.zip.
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping misc\mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\nps_chat.zip.
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\paradigms.zip.
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping misc\perluniprops.zip.
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pil.zip.
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pl196x.zip.
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping stemmers\porter_test.zip.
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pros_cons.zip.
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ptb.zip.
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\qc.zip.
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping stemmers\rslp.zip.
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\state_union.zip.
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\swadesh.zip.
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\switchboard.zip.
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping help\tagsets.zip.
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\timit.zip.
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\toolbox.zip.
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\udhr.zip.
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\verbnet3.zip.
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet_ic.zip.
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\words.zip.
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[55], line 40
#      38 diary_entries_path =  r'C:\Users\DELL\Desktop\Project\Untitled Folder\Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'  # Replace with the path to your dataset
#      39 with open(diary_entries_path, 'r') as file:
# ---> 40     lines = file.readlines()
#      42 dates = []
#      43 entries = []
#
# File D:\Anaconda\lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8f in position 171: character maps to <undefined>

# %%
import re
import pdfplumber
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from docx import Document

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Define a regex pattern for the date format
date_pattern = re.compile(r'(?:[A-Za-z]+, [A-Za-z]+ \d{1,2}, \d{4})')

# Function to insert newlines before and after each date in the text
def insert_newlines(text):
    # Add newlines before and after each date match
    text_with_newlines = date_pattern.sub(r'\n\n\n\g<0>:\n', text)
    return text_with_newlines

# Function to preprocess text
def preprocess_text(text):
    # Normalize text
    text = text.lower()
    text = re.sub(r'(?<!\w)([A-Za-z])\s+', r'\1', text)
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'[^\w\s\d]', '', text)

    # Tokenize text without stemming
    tokens = word_tokenize(text)

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]

    return ' '.join(filtered_tokens)

# Read the PDF file using pdfplumber
def extract_text_from_pdf(pdf_path):
    text_content = []
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text_content.append(page.extract_text())

    return ' '.join(text_content).replace('\n', ' ')

# Define the path for your PDF file and output file
pdf_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl.pdf'
output_word_file = 'Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'

# Extract text from PDF
pdf_text = extract_text_from_pdf(pdf_file_path)

# Add newlines before and after dates
pdf_text_with_newlines = insert_newlines(pdf_text)

# Now preprocess text excluding the dates
# Split the text by newlines and separate dates and non-date lines
lines = pdf_text_with_newlines.split('\n')
dates = []
non_date_lines = []

for line in lines:
    if date_pattern.match(line):
        dates.append(line)
    else:
        non_date_lines.append(line)

# Preprocess non-date lines
preprocessed_lines = [preprocess_text(line) for line in non_date_lines]

# Create a Word document
doc = Document()

# Iterate over dates and corresponding preprocessed lines
for date, line in zip(dates, preprocessed_lines):
    # Add date entry to document
    doc.add_heading(date + ":", level=1)
    doc.add_paragraph(line)

# Save the Word document
doc.save(output_word_file)

print("Preprocessing complete. Output saved to", output_word_file)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[64], line 51
#      48 output_word_file = 'Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'
#      50 # Extract text from PDF
# ---> 51 pdf_text = extract_text_from_pdf(pdf_file_path)
#      53 # Add newlines before and after dates
#      54 pdf_text_with_newlines = insert_newlines(pdf_text)
#
# Cell In[64], line 42, in extract_text_from_pdf(pdf_path)
#      40 with pdfplumber.open(pdf_path) as pdf:
#      41     for page in pdf.pages:
# ---> 42         text_content.append(page.extract_text())
#      44 return ' '.join(text_content).replace('\n', ' ')
#
# File D:\Anaconda\lib\site-packages\pdfplumber\page.py:507, in Page.extract_text(self, **kwargs)
#     506 def extract_text(self, **kwargs: Any) -> str:
# --> 507     return self.get_textmap(**kwargs).as_string
#
# File D:\Anaconda\lib\site-packages\pdfplumber\page.py:179, in textmap_cacher.<locals>.new_func(**kwargs)
#     178 def new_func(**kwargs: Any) -> TextMap:
# --> 179     return lru_cache()(func)(
#     180         **{
#     181             key: (tuple(value) if isinstance(value, list) else value)
#     182             for key, value in kwargs.items()
#     183         }
#     184     )
#
# File D:\Anaconda\lib\site-packages\pdfplumber\page.py:484, in Page._get_textmap(self, **kwargs)
#     482     defaults.update({"layout_height": self.height})
#     483 full_kwargs: Dict[str, Any] = {**defaults, **kwargs}
# --> 484 return utils.chars_to_textmap(self.chars, **full_kwargs)
#
# File D:\Anaconda\lib\site-packages\pdfplumber\container.py:50, in Container.chars(self)
#      48 @property
#      49 def chars(self) -> T_obj_list:
# ---> 50     return self.objects.get("char", [])
#
# File D:\Anaconda\lib\site-packages\pdfplumber\page.py:339, in Page.objects(self)
#     337 if hasattr(self, "_objects"):
#     338     return self._objects
# --> 339 self._objects: Dict[str, T_obj_list] = self.parse_objects()
#     340 return self._objects
#
# File D:\Anaconda\lib\site-packages\pdfplumber\page.py:422, in Page.parse_objects(self)
#     420 def parse_objects(self) -> Dict[str, T_obj_list]:
#     421     objects: Dict[str, T_obj_list] = {}
# --> 422     for obj in self.iter_layout_objects(self.layout._objs):
#     423         kind = obj["object_type"]
#     424         if kind in ["anno"]:
#
# File D:\Anaconda\lib\site-packages\pdfplumber\page.py:418, in Page.iter_layout_objects(self, layout_objects)
#     416     yield from self.iter_layout_objects(obj._objs)
#     417 else:
# --> 418     yield self.process_object(obj)
#
# File D:\Anaconda\lib\site-packages\pdfplumber\page.py:348, in Page.process_object(self, obj)
#     345 def process_object(self, obj: LTItem) -> T_obj:
#     346     kind = re.sub(lt_pat, "", obj.__class__.__name__).lower()
# --> 348     def process_attr(item: Tuple[str, Any]) -> Optional[Tuple[str, Any]]:
#     349         k, v = item
#     350         if k in ALL_ATTRS:
#
# File D:\Anaconda\lib\typing.py:309, in _tp_cache.<locals>.decorator.<locals>.inner(*args, **kwds)
#     306 @functools.wraps(func)
#     307 def inner(*args, **kwds):
#     308     try:
# --> 309         return cached(*args, **kwds)
#     310     except TypeError:
#     311         pass  # All real errors (not unhashable args) are raised below.
#
# KeyboardInterrupt:

# %%
import csv
import re
from docx import Document

# Step 3: Perform Temporal Sentiment Analysis
sentiment_analyzer = SentimentIntensityAnalyzer()

# Read the diary entries from the Word document
diary_entries_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'  # Replace with the path to your dataset

doc = Document(diary_entries_path)

lines = []
for paragraph in doc.paragraphs:
    line = paragraph.text.strip()
    if line:
        lines.append(line)

dates = []
entries = []

# Extract dates and entries from the lines
date_pattern = re.compile(r'(?:[A-Za-z]+, [A-Za-z]+ \d{1,2}, \d{4})')

for line in lines:
    line = line.strip()
    if line and ':' in line:
        match = date_pattern.search(line)
        if match:
            date = match.group(0)
            entry = line.split(':', 1)[1].strip()  # Split at the first occurrence of ':'
            dates.append(date.strip())
            entries.append(entry.strip())

# Print the extracted dates and entries
for date, entry in zip(dates, entries):
    print(f"Date: {date}, Entry: {entry}")

# Create a DataFrame with dates and entries
df = pd.DataFrame({'Date': dates, 'Text': entries})

# Print the DataFrame to verify the data
print(df)



# Group entries by date
grouped_entries = df.groupby('Date', group_keys=False)['Text'].apply(list)

# Step 4: Calculate emotion scores for each date
emotion_scores = {emotion: [] for emotion in nrc_lexicon['happy'].keys()}

for date, entries in grouped_entries.items():
    sentiment_scores = {emotion: 0 for emotion in nrc_lexicon['happy'].keys()}
    words_associated = {emotion: [] for emotion in nrc_lexicon['happy'].keys()}
    for entry in entries:
        tokens = word_tokenize(entry.lower())
        preprocessed_tokens = [token for token in tokens if token.isalpha() and token not in stop_words]
        for token in preprocessed_tokens:
            if token in nrc_lexicon:
                emotions_found = nrc_lexicon[token]
                for emotion, sentiment in emotions_found.items():
                    sentiment_scores[emotion] += sentiment
                    words_associated[emotion].append(token)

    for emotion, score in sentiment_scores.items():
        emotion_scores[emotion].append(score)

# Create a list of dictionaries to store the data
data = []
for date, emotions in zip(grouped_entries.keys(), zip(*emotion_scores.values())):
    entry = {
        'Date': date,
        'Number of Emotions': len(emotion_scores),
    }
    for emotion, score in zip(emotion_scores.keys(), emotions):
        entry[emotion.capitalize()] = score
        entry[emotion.capitalize() + ' Words'] = ' '.join(words_associated[emotion])
    data.append(entry)

# Write the data to a CSV file
csv_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\emotion_data.csv'  # Replace with the desired path to save the CSV file
fieldnames = ['Date', 'Number of Emotions'] + list(emotion_scores.keys()) + [emotion.capitalize() + ' Words' for emotion in emotion_scores.keys()]

with open(csv_file_path, 'w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(data)

print("CSV file created successfully.")
# Out:
# Empty DataFrame
# Columns: [Date, Text]
# Index: []
# CSV file created successfully.

# %%
# Out:
# Empty DataFrame
# Columns: [Date, Text]
# Index: []

# %%
import re
from docx import Document

def extract_date_entries_with_text(doc_file, output_file):
    doc = Document(doc_file)
    date_entries_with_text = []

    date_pattern = r"([A-Za-z]+),\s([A-Za-z]+)\s(\d{1,2}),\s(\d{4})"  # Date pattern, e.g., "Sunday, June 14, 1942"

    # Extract text from paragraphs
    paragraphs = [paragraph.text for paragraph in doc.paragraphs]
    text = "\n".join(paragraphs)

    matches = re.findall(date_pattern, text)
    for match in matches:
        day, month, num, year = match
        date = f"{day}, {month} {num}, {year}"
        index = text.index(date) + len(date)
        entry_text = text[index:].strip()
        date_entries_with_text.append((date, entry_text))

    # Filter date entries with the desired format
    filtered_entries = [(date, text) for date, text in date_entries_with_text if re.match(date_pattern, date)]

    # Create a new document and add extracted data
    output_doc = Document()
    for date, text in filtered_entries:
        output_doc.add_paragraph(f"Date: {date}")
        output_doc.add_paragraph(f"Text: {text}")
        output_doc.add_paragraph()

    # Save the output document
    output_doc.save(output_file)

# Example usage
doc_file = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'
output_file = 'output.docx'
extract_date_entries_with_text(doc_file, output_file)

# %%
import csv
import docx
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Step 1: Preprocess the Text
diary_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'  # Replace with the path to your Word document

# Read the diary text from the document
doc = docx.Document(diary_file_path)
diary_text = " ".join([paragraph.text for paragraph in doc.paragraphs])

# Tokenize and preprocess the text
stop_words = set(stopwords.words('english'))
tokens = word_tokenize(diary_text.lower())
preprocessed_tokens = [token for token in tokens if token.isalpha() and token not in stop_words]

# Step 2: Load the NRC Emotion Lexicon
nrc_lexicon_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\NRC-emotion-lexicon-wordlevel-alphabetized-v0.92.txt'  # Replace with the path to your downloaded lexicon

# Create a dictionary to store the emotion mappings
nrc_lexicon = {}
with open(nrc_lexicon_path, "r") as file:
    for line in file:
        word, emotion, value = line.strip().split("\t")
        if word in nrc_lexicon:
            nrc_lexicon[word][emotion] = int(value)
        else:
            nrc_lexicon[word] = {emotion: int(value)}

# Step 3: Calculate Sentiment Score
emotions = {'joy': set(), 'sadness': set(), 'anger': set(), 'fear': set(), 'trust': set(), 'disgust': set(),
            'surprise': set(), 'anticipation': set(), 'excitement': set()}
sentiment_score = 0

for word in preprocessed_tokens:
    if word in nrc_lexicon:
        emotions_found = nrc_lexicon[word]
        for emotion, sentiment in emotions_found.items():
            if sentiment == 1 and emotion in emotions:
                emotions[emotion].add(word)
                sentiment_score += sentiment

# Step 4: Write Output to CSV
output_file = 'output1.csv'

with open(output_file, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Emotion', 'Count', 'Words', 'Sentiment Score'])

    for emotion, words in emotions.items():
        count = len(words)
        distinct_words = ", ".join(words)
        emotion_sentiment_score = sum([nrc_lexicon[word][emotion] for word in words])
        writer.writerow([emotion.capitalize(), count, distinct_words, emotion_sentiment_score])

    writer.writerow(['Combined Sentiment Score:', sentiment_score])

print(f"Output written to {output_file} in CSV format.")
# Out:
# Output written to output1.csv in CSV format.

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import csv
import docx
import re
from datetime import datetime

# Step 1: Preprocess the Text
diary_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'  # Replace with the path to your Word document

# Read the diary text from the document
doc = docx.Document(diary_file_path)
diary_text = " ".join([paragraph.text for paragraph in doc.paragraphs])

# Step 2: Extract date entries with the format "Sunday June 21 1942"
date_entries = re.findall(r"[A-Za-z]+ [A-Za-z]+ \d{1,2} \d{4}", diary_text)

# Convert date entries to a consistent format
formatted_dates = []
for entry in date_entries:
    try:
        date_obj = datetime.strptime(entry, "%A %B %d %Y")
        formatted_date = date_obj.strftime("%Y-%m-%d")  # Format as YYYY-MM-DD
        formatted_dates.append(formatted_date)
    except ValueError:
        pass

# Sort the date entries in ascending order
formatted_dates.sort()

# Step 3: Print the extracted date entries
print("Date Entries:")
if len(formatted_dates) == 0:
    print("No date entries found")
else:
    for date_entry in formatted_dates:
        print(date_entry)

# Step 4: Write Output to CSV
output_file = 'output_with_date.csv'

with open(output_file, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Date'])

    if len(formatted_dates) == 0:
        writer.writerow(['No date entries found'])
    else:
        for date_entry in formatted_dates:
            writer.writerow([date_entry])

    print(f"Output written to {output_file} in CSV format.")
# Out:
# Date Entries:
# 1942-06-14
# 1942-06-15
# 1942-06-20
# 1942-06-21
# 1942-06-24
# 1942-07-01
# 1942-07-05
# 1942-07-08
# 1942-07-09
# 1942-07-10
# 1942-07-11
# 1942-07-12
# 1942-08-14
# 1942-08-21
# 1942-09-02
# 1942-09-21
# 1942-09-25
# 1942-09-27
# 1942-09-29
# 1942-10-01
# 1942-10-03
# 1942-10-07
# 1942-10-14
# 1942-10-20
# 1942-10-29
# 1942-11-02
# 1942-11-05
# 1942-11-07
# 1942-11-10
# 1942-11-12
# 1942-11-17
# 1942-11-19
# 1942-11-20
# 1942-12-07
# 1942-12-10
# 1942-12-13
# 1942-12-22
# 1943-01-13
# 1943-01-30
# 1943-02-05
# 1943-02-27
# 1943-03-04
# 1943-03-10
# 1943-03-12
# 1943-03-18
# 1943-03-19
# 1943-03-25
# 1943-03-27
# 1943-04-01
# 1943-04-02
# 1943-04-27
# 1943-05-01
# 1943-05-02
# 1943-05-02
# 1943-05-18
# 1943-06-13
# 1943-06-15
# 1943-07-11
# 1943-07-13
# 1943-07-16
# 1943-07-23
# 1943-07-26
# 1943-07-29
# 1943-08-03
# 1943-08-05
# 1943-08-07
# 1943-08-09
# 1943-08-10
# 1943-08-23
# 1943-09-10
# 1943-09-16
# 1943-09-29
# 1943-10-17
# 1943-11-03
# 1943-11-11
# 1943-11-17
# 1943-11-27
# 1943-12-06
# 1943-12-24
# 1943-12-27
# 1943-12-29
# 1943-12-30
# 1944-01-02
# 1944-01-06
# 1944-01-06
# 1944-01-12
# 1944-01-15
# 1944-01-22
# 1944-01-24
# 1944-01-28
# 1944-01-28
# 1944-01-30
# 1944-02-03
# 1944-02-08
# 1944-02-12
# 1944-02-14
# 1944-02-15
# 1944-02-16
# 1944-02-17
# 1944-02-18
# 1944-02-19
# 1944-02-20
# 1944-02-27
# 1944-02-28
# 1944-03-01
# 1944-03-02
# 1944-03-04
# 1944-03-06
# 1944-03-08
# 1944-03-10
# 1944-03-11
# 1944-03-12
# 1944-03-14
# 1944-03-16
# 1944-03-16
# 1944-03-17
# 1944-03-18
# 1944-03-19
# 1944-03-20
# 1944-03-23
# 1944-03-24
# 1944-03-25
# 1944-03-27
# 1944-03-28
# 1944-03-29
# 1944-03-31
# 1944-04-01
# 1944-04-03
# 1944-04-05
# 1944-04-06
# 1944-04-11
# 1944-04-14
# 1944-04-15
# 1944-04-16
# 1944-04-17
# 1944-04-19
# 1944-04-25
# 1944-04-27
# 1944-04-28
# 1944-05-02
# 1944-05-03
# 1944-05-05
# 1944-05-06
# 1944-05-08
# 1944-05-09
# 1944-05-10
# 1944-05-11
# 1944-05-11
# 1944-05-13
# 1944-05-16
# 1944-05-19
# 1944-05-20
# 1944-05-25
# 1944-05-26
# 1944-05-31
# 1944-06-02
# 1944-06-05
# 1944-06-06
# 1944-06-09
# 1944-06-13
# 1944-06-16
# 1944-06-23
# 1944-06-27
# 1944-06-30
# 1944-07-06
# 1944-07-08
# 1944-07-21
# 1944-08-01
# Output written to output_with_date.csv in CSV format.

# %%
import csv
import docx
import re
from datetime import datetime
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Step 1: Preprocess the Text
diary_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'  # Replace with the path to your Word document

# Read the diary text from the document
doc = docx.Document(diary_file_path)
diary_text = " ".join([paragraph.text for paragraph in doc.paragraphs])

# Tokenize and preprocess the text
stop_words = set(stopwords.words('english'))
tokens = word_tokenize(diary_text.lower())
preprocessed_tokens = [token for token in tokens if token.isalpha() and token not in stop_words]

# Step 2: Extract date entries from the diary text
date_entries = re.findall(r"[A-Za-z]+ [A-Za-z]+ \d{1,2} \d{4}", diary_text)

# Convert date entries to a consistent format
formatted_dates = []
for entry in date_entries:
    try:
        date_obj = datetime.strptime(entry, "%A, %B %d, %Y")  # Updated date format
        formatted_date = date_obj.strftime("%Y-%m-%d")  # Format as YYYY-MM-DD
        formatted_dates.append(formatted_date)
    except ValueError:
        pass

# Sort the date entries in ascending order
formatted_dates.sort()

# Step 3: Load the NRC Emotion Lexicon
nrc_lexicon_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\NRC-emotion-lexicon-wordlevel-alphabetized-v0.92.txt'  # Replace with the path to your downloaded lexicon

# Create a dictionary to store the emotion mappings
nrc_lexicon = {}
with open(nrc_lexicon_path, "r") as file:
    for line in file:
        word, emotion, value = line.strip().split("\t")
        if word in nrc_lexicon:
            nrc_lexicon[word][emotion] = int(value)
        else:
            nrc_lexicon[word] = {emotion: int(value)}

# Step 4: Calculate Emotions, Word Counts, and Sentiment Score for Each Day
data = []
for date_entry in formatted_dates:
    emotions = {'joy': set(), 'sadness': set(), 'anger': set(), 'fear': set(), 'trust': set(), 'disgust': set(),
                'surprise': set(), 'anticipation': set(), 'excitement': set()}
    sentiment_score = 0

    # Filter tokens that belong to the current date entry
    tokens_for_date = []
    for token in preprocessed_tokens:
        if date_entry in token:
            tokens_for_date.append(token)

    for word in tokens_for_date:
        if word in nrc_lexicon:
            emotions_found = nrc_lexicon[word]
            for emotion, sentiment in emotions_found.items():
                if sentiment == 1 and emotion in emotions:
                    emotions[emotion].add(word)
            sentiment_score += sentiment

    # Calculate word counts for each emotion
    word_counts = {emotion: len(words) for emotion, words in emotions.items()}

    # Append data for the current day to the list
    data.append([date_entry, emotions, word_counts, sentiment_score])

# Step 5: Write Output to CSV
output_file = 'diary_emotions.csv'

with open(output_file, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Date', 'Emotions', 'Word Counts', 'Sentiment Score'])

    for entry in data:
        date_entry = entry[0]
        emotions = entry[1]
        word_counts = entry[2]
        sentiment_score = entry[3]

        writer.writerow([date_entry, emotions, word_counts, sentiment_score])
        print(f"Data written for {date_entry}")

print(f"Output written to {output_file} in CSV format.")
# Out:
# Output written to diary_emotions.csv in CSV format.

# %%
import nltk
print(nltk.__version__)
# Out:
# 3.8.1

# %%
import re
from datetime import datetime

# Diary text containing the date
diary_text = "Sunday, June 21, 1942 - Today is a sunny day."

# Regular expression pattern to match the date
date_entries = re.findall(r"[A-Za-z]+ [A-Za-z]+ \d{1,2} \d{4}", diary_text)

# Extract the date from the text
match = re.search(date_pattern, diary_text)

if match:
    # Extract the individual components of the date
    day = match.group(1)
    month = match.group(2)
    day_number = match.group(3)
    year = match.group(4)

    # Convert the date components to a datetime object
    date = datetime.strptime(f"{month} {day_number}, {year}", "%B %d, %Y")

    # Format the date as desired
    formatted_date = date.strftime("%A, %B %d, %Y")

    print(f"Extracted Date: {formatted_date}")
else:
    print("No date found in the text.")
# Out:
# Extracted Date: Sunday, June 21, 1942

# %%
import csv
import docx
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Step 1: Preprocess the Text
diary_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'  # Replace with the path to your Word document

# Read the diary text from the document
doc = docx.Document(diary_file_path)
diary_text = " ".join([paragraph.text for paragraph in doc.paragraphs])

# Tokenize and preprocess the text
stop_words = set(stopwords.words('english'))
tokens = word_tokenize(diary_text.lower())
preprocessed_tokens = [token for token in tokens if token.isalpha() and token not in stop_words]

# Step 2: Load the NRC Emotion Lexicon
nrc_lexicon_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\NRC-emotion-lexicon-wordlevel-alphabetized-v0.92.txt'  # Replace with the path to your downloaded lexicon

# Create a dictionary to store the emotion mappings
nrc_lexicon = {}
with open(nrc_lexicon_path, "r") as file:
    for line in file:
        word, emotion, value = line.strip().split("\t")
        if word in nrc_lexicon:
            nrc_lexicon[word][emotion] = int(value)
        else:
            nrc_lexicon[word] = {emotion: int(value)}

# Step 3: Calculate Sentiment Score
emotions = {'joy': set(), 'sadness': set(), 'anger': set(), 'fear': set(), 'trust': set(), 'disgust': set(),
            'surprise': set(), 'anticipation': set(), 'excitement': set()}
sentiment_score = 0

for word in preprocessed_tokens:
    if word in nrc_lexicon:
        emotions_found = nrc_lexicon[word]
        for emotion, sentiment in emotions_found.items():
            if sentiment == 1 and emotion in emotions:
                emotions[emotion].add(word)
                sentiment_score += sentiment

# Step 4: Write Output to CSV
output_file = 'output.csv'

with open(output_file, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Emotion', 'Count', 'Words', 'Sentiment Score'])

    for emotion, words in emotions.items():
        count = len(words)
        distinct_words = ", ".join(words)
        emotion_sentiment_score = sum([nrc_lexicon[word][emotion] for word in words])
        writer.writerow([emotion.capitalize(), count, distinct_words, emotion_sentiment_score])

    writer.writerow(['Combined Sentiment Score:', sentiment_score])

print(f"Output written to {output_file} in CSV format.")
# Out:
# Output written to output.csv in CSV format.

# %%
import re
import csv
import docx
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Step 1: Preprocess the Text
diary_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'  # Replace with the path to your Word document

# Read the diary text from the document
doc = docx.Document(diary_file_path)
diary_text = " ".join([paragraph.text for paragraph in doc.paragraphs])

# Tokenize and preprocess the text
stop_words = set(stopwords.words('english'))
tokens = word_tokenize(diary_text.lower())
preprocessed_tokens = [token for token in tokens if token.isalpha() and token not in stop_words]

# Step 2: Load the NRC Emotion Lexicon
nrc_lexicon_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\NRC-emotion-lexicon-wordlevel-alphabetized-v0.92.txt'  # Replace with the path to your downloaded lexicon

# Create a dictionary to store the emotion mappings
nrc_lexicon = {}
with open(nrc_lexicon_path, "r") as file:
    for line in file:
        word, emotion, value = line.strip().split("\t")
        if word in nrc_lexicon:
            nrc_lexicon[word][emotion] = int(value)
        else:
            nrc_lexicon[word] = {emotion: int(value)}

# Step 3: Extract Dates from the Diary Text
date_regex = r'\b\d{4}-\d{2}-\d{2}\b'
date_entries = re.findall(date_regex, diary_text)

# Step 4: Calculate Sentiment Scores for Each Date Entry
output_file = 'output_emotions_by_date.csv'

with open(output_file, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Date', 'Emotion', 'Count', 'Words', 'Sentiment Score'])

    for date_entry in date_entries:
        emotions = {'joy': set(), 'sadness': set(), 'anger': set(), 'fear': set(), 'trust': set(), 'disgust': set(),
                    'surprise': set(), 'anticipation': set(), 'excitement': set()}
        word_counts = {emotion: 0 for emotion in emotions}
        sentiment_score = 0

        for word in preprocessed_tokens:
            if word in nrc_lexicon:
                emotions_found = nrc_lexicon[word]
                for emotion, sentiment in emotions_found.items():
                    if sentiment == 1 and emotion in emotions:
                        emotions[emotion].add(word)
                        word_counts[emotion] += 1
                        sentiment_score += sentiment

        writer.writerow([date_entry, 'Combined', sum(word_counts.values()), '', sentiment_score])

        for emotion, words in emotions.items():
            count = word_counts[emotion]
            distinct_words = ", ".join(words)
            writer.writerow([date_entry, emotion.capitalize(), count, distinct_words, sentiment_score])

print(f"Emotions extracted for the specified date entries. Output written to {output_file} in CSV format.")
# Out:
# Emotions extracted for the specified date entries. Output written to output_emotions_by_date.csv in CSV format.

# %%
import re
import pdfplumber
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from docx import Document
import nltk

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Define a regex pattern for the date format
date_pattern = re.compile(r'(?:[A-Za-z]+, [A-Za-z]+ \d{1,2}, \d{4})')

# Function to insert newlines before and after each date in the text
def insert_newlines(text):
    # Add newlines before and after each date match
    text_with_newlines = date_pattern.sub(r'\n\n\n\g<0>\n', text)
    return text_with_newlines

# Function to preprocess text
def preprocess_text(text):
    # Normalize text
    text = text.lower()
    text = re.sub(r'(?<!\w)([A-Za-z])\s+', r'\1', text)
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'[^\w\s\d]', '', text)

    # Tokenize text without stemming
    tokens = word_tokenize(text)

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]

    return ' '.join(filtered_tokens)

# Read the PDF file using pdfplumber
def extract_text_from_pdf(pdf_path):
    text_content = []
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text_content.append(page.extract_text())

    return ' '.join(text_content).replace('\n', ' ')

# Define the path for your PDF file and output file
pdf_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl.pdf'
output_word_file = 'Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'

# Extract text from PDF
pdf_text = extract_text_from_pdf(pdf_file_path)

# Add newlines before and after dates
pdf_text_with_newlines = insert_newlines(pdf_text)

# Now preprocess text excluding the dates
# Split the text by newlines, preprocess non-date lines, and rejoin the text
processed_lines = [preprocess_text(line) for line in pdf_text_with_newlines.split('\n')]
preprocessed_text = '\n'.join(processed_lines)

# Create a Word document
doc = Document()
doc.add_paragraph(preprocessed_text)

# Save the Word document
doc.save(output_word_file)

print("Preprocessing complete. Output saved to", output_word_file)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Preprocessing complete. Output saved to Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx

# %%
import csv
import docx
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from datetime import datetime
import re

# Load the NRC Emotion Lexicon
nrc_lexicon_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\NRC-emotion-lexicon-wordlevel-alphabetized-v0.92.txt'  # Replace with the path to your downloaded lexicon

# Create a dictionary to store the emotion mappings
nrc_lexicon = {}
with open(nrc_lexicon_path, "r") as file:
    for line in file:
        word, emotion, value = line.strip().split("\t")
        if word in nrc_lexicon:
            nrc_lexicon[word][emotion] = int(value)
        else:
            nrc_lexicon[word] = {emotion: int(value)}

# Step 1: Preprocess the Text for Date Extraction
diary_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'
doc = docx.Document(diary_file_path)
diary_text = " ".join([paragraph.text for paragraph in doc.paragraphs])

# Step 2: Extract date entries with the format "Sunday June 21 1942"
date_entries = re.findall(r"[A-Za-z]+ [A-Za-z]+ \d{1,2} \d{4}", diary_text)

# Convert date entries to a consistent format
formatted_dates = []
for entry in date_entries:
    try:
        date_obj = datetime.strptime(entry, "%A %B %d %Y")
        formatted_date = date_obj.strftime("%Y-%m-%d")  # Format as YYYY-MM-DD
        formatted_dates.append(formatted_date)
    except ValueError:
        pass

# Sort the date entries in ascending order
formatted_dates.sort()

# Step 3: Print the extracted date entries
print("Date Entries:")
if len(formatted_dates) == 0:
    print("No date entries found")
else:
    for date_entry in formatted_dates:
        print(date_entry)

# Step 4: Write Output to CSV
output_file = 'output_with_date.csv'

with open(output_file, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Date'])

    if len(formatted_dates) == 0:
        writer.writerow(['No date entries found'])
    else:
        for date_entry in formatted_dates:
            writer.writerow([date_entry])

    print(f"Output written to {output_file} in CSV format.")

# Create a function to extract paragraphs for a specific date range
def extract_paragraphs_for_date_range(start_date, end_date, doc):
    paragraphs_in_date_range = []
    capturing = False

    for paragraph in doc.paragraphs:
        if start_date in paragraph.text:
            capturing = True
# 1944-05-06
# 1944-05-08
# 1944-05-09
# 1944-05-10
# 1944-05-11
# 1944-05-11
# 1944-05-13
# 1944-05-16
# 1944-05-19
# 1944-05-20
# 1944-05-25
# 1944-05-26
# 1944-05-31
# 1944-06-02
# 1944-06-05
# 1944-06-06
# 1944-06-09
# 1944-06-13
# 1944-06-16
# 1944-06-23
# 1944-06-27
# 1944-06-30
# 1944-07-06
# 1944-07-08
# 1944-07-21
# 1944-08-01
# Output written to output_with_date.csv in CSV format.
# Paragraphs between 1942-06-14 and 1942-06-15:

# %%
import docx
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Load the NRC Emotion Lexicon
nrc_lexicon_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\NRC-emotion-lexicon-wordlevel-alphabetized-v0.92.txt'
nrc_lexicon = {}

with open(nrc_lexicon_path, "r") as file:
    for line in file:
        word, emotion, value = line.strip().split("\t")
        if word in nrc_lexicon:
            nrc_lexicon[word][emotion] = int(value)
        else:
            nrc_lexicon[word] = {emotion: int(value)}

# Function to preprocess text and extract emotions
def extract_emotions_from_text(text):
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text.lower())
    preprocessed_tokens = [token for token in tokens if token.isalpha() and token not in stop_words]

    emotions = {'joy': set(), 'sadness': set(), 'anger': set(), 'fear': set(),
                'trust': set(), 'disgust': set(), 'surprise': set(), 'anticipation': set(), 'excitement': set()}

    for word in preprocessed_tokens:
        if word in nrc_lexicon:
            emotions_found = nrc_lexicon[word]
            for emotion, sentiment in emotions_found.items():
                if sentiment == 1 and emotion in emotions:
                    emotions[emotion].add(word)

    return emotions

# Function to find date pairs and extract emotions and words between them
def extract_emotions_between_date_pairs(diary_text):
    date_entries = re.findall(r"[A-Za-z]+ [A-Za-z]+ \d{1,2} \d{4}", diary_text)
    emotions_data_between_dates = []

    for i in range(len(date_entries) - 1):
        date1 = date_entries[i]
        date2 = date_entries[i + 1]

        # Find the text between two dates
        text_between_dates = re.search(f"{date1}(.+?){date2}", diary_text, re.DOTALL)

        if text_between_dates:
            text_between_dates = text_between_dates.group(1).strip()

            # Extract emotions from the text between dates
            emotions_data = extract_emotions_from_text(text_between_dates)

            # Append date range to the emotions data
            emotions_data['Date Range'] = f"{date1} to {date2}"
            emotions_data_between_dates.append(emotions_data)

    return emotions_data_between_dates

# Specify the document path
docx_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'

# Read the diary text from the document
doc = docx.Document(docx_path)
diary_text = "\n".join([paragraph.text for paragraph in doc.paragraphs])

# Extract emotions between date pairs
emotions_between_dates = extract_emotions_between_date_pairs(diary_text)

# Print the emotions data between date pairs
for emotions_data in emotions_between_dates:
    print(f"\nDate Range: {emotions_data['Date Range']}")
    for emotion, words in emotions_data.items():
        if emotion != 'Date Range':
            count = len(words)
            distinct_words = ", ".join(words)
            print(f"{emotion.capitalize()}\t{count}\t{distinct_words}")
# Out:
# Date Range: born june 12 1929 to adiary june 12 1942
# Joy	2	young, birthday
# Sadness	2	imprisoned, holocaust
# Anger	2	imprisoned, holocaust
# Fear	2	imprisoned, holocaust
# Trust	1	frank
# Disgust	2	imprisoned, holocaust
# Surprise	2	young, birthday
# Anticipation	2	young, birthday
# Excitement	0
#
# Date Range: adiary june 12 1942 to dated august 1 1944
# Joy	1	diary
# Sadness	2	exile, suffering
# Anger	1	exile
# Fear	4	exile, suffering, war, government
# Trust	4	frank, diary, eyewitness, accounts
# Disgust	1	suffering
# Surprise	0
# Anticipation	3	public, time, edition
# Excitement	0
#
# Date Range: dated august 1 1944 to born september 9 1890
# Joy	6	respect, young, sex, fulfill, diary, found
# Sadness	1	deportation
# Anger	3	deportation, deserve, bear
# Fear	6	war, bear, hiding, deportation, examination, forced
# Trust	15	respect, safekeeping, genuine, exhaustive, frank, real, sex, institute, secret, authenticity, general, integrity, diary, deserve, found
# Disgust	0
# Surprise	2	young, examination
# Anticipation	9	investigation, intended, young, sex, edition, long, deserve, time, respect
# Excitement	0
#
# Date Range: born september 9 1890 to born march 31 1889
# Joy	0
# Sadness	0
# Anger	0
# Fear	0
# Trust	0
# Disgust	0
# Surprise	0
# Anticipation	0
# Excitement	0
#
# Date Range: born march 31 1889 to born november 8 1926
# Joy	0
# Sadness	0
# Anger	0
# Fear	0
# Trust	0
# Disgust	0
# Surprise	0
# Anticipation	0
# Excitement	0
#
# Date Range: born november 8 1926 to born april 30 1889
# Joy	0
# Sadness	0
# Anger	0
# Fear	0
# Trust	0
# Disgust	0
# Surprise	0
# Anticipation	0
# Excitement	0
#
# Date Range: born april 30 1889 to support june 12 1942
# Joy	1	comfort
# Sadness	1	inappropriate
# Anger	2	inappropriate, bear
# Fear	1	bear
# Trust	2	confide, comfort
# Disgust	1	inappropriate
# Surprise	0
# Anticipation	2	comfort, edition
# Excitement	0
#
# Date Range: support june 12 1942 to anne september 28 1942
# Joy	1	comfort
# Sadness	0
# Anger	0
# Fear	0
# Trust	2	confide, comfort
# Disgust	0
# Surprise	0
# Anticipation	1	comfort
# Excitement	0
#
# Date Range: anne september 28 1942 to sunday june 14 1942
# Joy	1	comfort
# Sadness	0
# Anger	0
# Fear	0
# Trust	1	comfort
# Disgust	0
# Surprise	0
# Anticipation	2	wait, comfort
# Excitement	0
#
# Date Range: sunday june 14 1942 to monday june 15 1942
# Joy	8	good, happy, welcomed, wonderful, friend, cream, mother, birthday
# Sadness	4	ill, mistake, dislocated, mother
# Anger	3	ill, dislocated, lying
# Fear	2	ill, dislocated
# Trust	8	good, school, happy, wonderful, friend, mother, aunt, expert
# Disgust	3	ill, dislocated, lying
# Surprise	5	curiosity, good, wonderful, cream, birthday
# Anticipation	7	curiosity, good, happy, cream, mother, birthday, time
# Excitement	0
#
# Date Range: monday june 15 1942 to born june 12 1929
# Joy	18	beer, diary, feeling, laugh, loving, love, flirt, adorable, friend, birthday, mother, deal, surprise, pretty, silly, kind, true, helpful
# Sadness	19	problem, quiet, listless, mother, rob, ruined, offended, interested, case, tough, ill, fault, obnoxious, harry, rumor, depressed, feeling, badly, terrific
# Anger	11	feeling, lying, offended, harry, hit, ill, depressed, rob, punishment, ruined, obnoxious
# Fear	14	homework, feeling, problem, plunge, case, ruined, mistaken, ill, change, surprise, rob, punishment, nervous, depressed
# Trust	19	planning, top, friend, mother, true, provide, facts, prefer, helpful, patience, kind, loving, father, feeling, school, flirt, diary, pretty, deal
# Disgust	11	vulgar, feeling, lying, boy, interested, ill, dirty, rob, punishment, ruined, obnoxious
# Surprise	7	feeling, laugh, catch, flirt, birthday, surprise, deal
# Anticipation	12	feeling, start, planning, patience, top, flirt, birthday, mother, deal, pretty, time, nervous
# Excitement	0
#
# Date Range: born june 12 1929 to date june 20 1942
# Joy	38	comfort, young, happy, wonderful, star, adorable, friend, mother, true, found, laugh, love, sex, welcomed, birthday, shopping, freedom, entertainment, helpful, good, safe, fulfill, present, cream, beauty, surprise, nursery, kind, silly, respect, beer, loving, celebration, feeling, flirt, diary, pretty, deal
# Sadness	29	problem, quiet, exile, listless, dislocated, mother, rob, ruined, inappropriate, offended, interested, case, tough, ill, deportation, fault, obnoxious, harry, anxiety, suffering, imprisoned, mistake, rumor, depressed, feeling, badly, holocaust, sick, terrific
# Anger	21	lying, exile, dislocated, rob, deserve, ruined, inappropriate, offended, bear, hit, ill, deportation, fighting, punishment, obnoxious, harry, anxiety, imprisoned, depressed, feeling, holocaust
# Fear	29	problem, exile, mistaken, dislocated, rob, ruined, bear, case, government, hiding, ill, change, deportation, punishment, nervous, plunge, anxiety, suffering, imprisoned, surprise, examination, forced, depressed, homework, fled, war, feeling, operation, holocaust
# Trust	55	safekeeping, exhaustive, accounts, comfort, planning, happy, top, wonderful, star, friend, mother, eyewitness, deserve, aunt, true, found, provide, facts, prefer, genuine, frank, confide, sex, institute, authenticity, shopping, freedom, entertainment, helpful, good, safe, patience, present, secret, integrity, nursery, teacher, kind, celebration, respect, expert, loving, real, feeling, father, school, wear, operation, director, flirt, principal, general, diary, pretty, deal
# Disgust	17	feeling, lying, boy, interested, rob, holocaust, ill, suffering, dirty, imprisoned, dislocated, sick, vulgar, punishment, ruined, inappropriate, obnoxious
# Surprise	17	curiosity, feeling, good, surprise, laugh, catch, young, present, wonderful, flirt, shopping, cream, birthday, examination, entertainment, deal, celebration
# Anticipation	34	comfort, young, planning, happy, top, wait, star, mother, deserve, curiosity, investigation, sex, edition, birthday, shopping, entertainment, nervous, good, intended, patience, anxiety, present, cream, long, public, celebration, respect, feeling, start, arrival, flirt, pretty, time, deal
# Excitement	0
#
# Date Range: date june 20 1942 to saturday june 20 1942
# Joy	1	diary
# Sadness	0
# Anger	0
# Fear	0
# Trust	1	diary
# Disgust	0
# Surprise	0
# Anticipation	0
# Excitement	0
#
# Date Range: saturday june 20 1942 to sunday june 21 1942
# Joy	10	money, friendship, young, generous, oasis, friend, passionate, cream, mother, silly
# Sadness	5	quiet, case, bad, hell, mother
# Anger	6	money, hot, bad, hell, uncertain, hunting
# Fear	5	case, bad, hell, uncertain, hunting
# Trust	11	father, money, friendship, school, oasis, friend, manage, passionate, generous, mother, innocent
# Disgust	3	hell, bad, uncertain
# Surprise	5	money, young, uncertain, cream, surprised
# Anticipation	12	money, start, long, young, tomorrow, oasis, hunting, passionate, cream, mother, thought, time
# Excitement	0
#
# Date Range: sunday june 21 1942 to wednesday june 24 1942
# Joy	9	laugh, joy, satisfied, friend, vacation, mother, baby, pretty, beautiful
# Sadness	11	worried, exhausted, quiet, complain, lose, death, necessity, sick, mad, mother, leave
# Anger	10	arguments, complain, lose, death, mistress, angry, mad, words, punishment, ridiculous
# Fear	5	homework, death, lose, mad, punishment
# Trust	6	father, frank, convincing, friend, mother, pretty
# Disgust	9	quack, lose, death, mistress, sick, angry, mad, punishment, ridiculous
# Surprise	8	laugh, lose, death, break, leave, trick, unpredictable, suddenly
# Anticipation	7	death, wait, vacation, mother, thought, pretty, time
# Excitement	0
#
# Date Range: wednesday june 24 1942 to wednesday july 1 1942
# Joy	8	luxury, pleasant, good, unexpected, goodness, friend, vacation, kind
# Sadness	4	ill, fell, torment, fault
# Anger	3	ill, torment, stolen
# Fear	3	ill, torment, unexpected
# Trust	8	father, pleasant, safekeeping, good, school, goodness, friend, kind
# Disgust	2	ill, boy
# Surprise	5	pleasant, good, unexpected, goodness, surprised
# Anticipation	7	pleasant, good, unexpected, goodness, vacation, long, time
# Excitement	0
#
# Date Range: wednesday july 1 1942 to sunday july 5 1942
# Joy	10	promise, good, young, miracle, love, finally, sweet, praise, marry, mother
# Sadness	6	falling, ill, shell, mother, apologize, hanging
# Anger	4	ill, hanging, shell, furious
# Fear	8	war, ill, shell, hide, marry, watch, hanging, nervous
# Trust	11	father, promise, good, miracle, finally, fixed, sweet, praise, marry, mother, apologize
# Disgust	5	boy, finally, ill, furious, hanging
# Surprise	8	good, young, miracle, finally, shell, sweet, marry, guess
# Anticipation	11	good, young, miracle, finally, sweet, marry, mother, watch, time, nervous, bye
# Excitement	0
#
# Date Range: sunday july 5 1942 to wednesday july 8 1942
# Joy	13	good, food, brilliant, enjoy, happy, graduation, pleased, finally, satisfied, baby, ceremony, deal, true
# Sadness	9	awful, leave, case, somber, bad, fall, lost, absent, worry
# Anger	4	bad, words, awful, screaming
# Fear	9	homework, awful, screaming, case, graduation, bad, hiding, worry, nervous
# Trust	14	father, good, school, accord, enjoy, happy, graduation, finally, usual, deal, brilliant, food, agreed, true
# Disgust	4	screaming, bad, awful, finally
# Surprise	6	good, leave, graduation, finally, ceremony, deal
# Anticipation	14	neighborhood, good, enjoy, happy, graduation, wait, finally, nervous, expected, long, brilliant, worry, time, deal
# Excitement	0
#
# Date Range: wednesday july 8 1942 to thursday july 9 1942
# Joy	8	destination, finally, goodness, friend, mother, diary, sun, alive
# Sadness	12	destination, exhausted, quiet, stripped, cry, ill, lonely, hospital, mother, fell, leave, suffocating
# Anger	7	stripped, hot, agitated, shock, ill, lonely, pound
# Fear	13	destination, stripped, creature, unknown, stunned, shock, ill, lonely, hiding, hospital, hide, suspense, suffocating
# Trust	12	father, dare, important, leading, finally, goodness, friend, hospital, mother, diary, sun, alive
# Disgust	6	stripped, creature, finally, ill, lonely, suffocating
# Surprise	9	destination, shock, finally, goodness, stunned, leave, sun, suspense, suddenly
# Anticipation	15	dare, destination, stripped, long, tomorrow, unknown, wait, finally, goodness, time, mother, thought, sun, suspense, alive
# Excitement	0
#
# Date Range: thursday july 9 1942 to friday july 10 1942
# Joy	7	sympathetic, young, lovely, star, elegant, mother, kind
# Sadness	8	dark, lovely, ill, black, gray, mother, leave, sympathetic
# Anger	1	ill
# Fear	4	hiding, ill, suspect, sympathetic
# Trust	16	father, ground, sympathetic, frank, top, occupant, lovely, star, explain, agreed, secret, fact, general, mother, word, kind
# Disgust	3	ill, toilet, gray
# Surprise	4	young, surprised, leave, lovely
# Anticipation	8	coming, long, young, top, lovely, star, plan, mother
# Excitement	0
#
# Date Range: friday july 10 1942 to saturday july 11 1942
# Joy	3	mother, clean, shopping
# Sadness	5	unable, exhausted, miserable, mother, fell
# Anger	2	miserable, words
# Fear	1	change
# Trust	6	father, clean, secret, shopping, mother, continue
# Disgust	2	mess, miserable
# Surprise	1	shopping
# Anticipation	7	arrival, happen, shopping, long, time, mother, continue
# Excitement	0
#
# Date Range: saturday july 11 1942 to sunday july 12 1942
# Joy	6	art, fun, cheerful, vacation, mother, kind
# Sadness	10	shot, doubt, art, quiet, bad, anxiety, ill, black, dismal, mother
# Anger	4	ill, shot, bad, anxiety
# Fear	10	shot, doubt, bad, anxiety, hiding, ill, afraid, dismal, hide, nervous
# Trust	4	father, doubt, kind, mother
# Disgust	4	ill, cough, bad, dismal
# Surprise	3	shot, art, cheerful
# Anticipation	12	art, start, fun, arrival, anxiety, arrive, vacation, clock, mother, immediately, time, nervous
# Excitement	0
#
# Date Range: sunday july 12 1942 to friday august 14 1942
# Joy	7	amusing, sweet, praised, mother, birthday, diary, deal
# Sadness	4	mother, shell, wound, broke
# Anger	2	shell, wound
# Fear	5	war, broke, shell, wound, dangerous
# Trust	6	fill, fact, sweet, mother, diary, deal
# Disgust	0
# Surprise	4	shell, sweet, deal, birthday
# Anticipation	6	start, sweet, birthday, mother, time, deal
# Excitement	0
#
# Date Range: friday august 14 1942 to friday august 21 1942
# Joy	4	amusement, kind, vivid, found
# Sadness	7	deserted, distraught, interested, late, unrest, cross, leave
# Anger	2	deserted, cross
# Fear	8	deserted, harm, military, unrest, horrified, afraid, thirteenth, cross
# Trust	8	civilization, frank, planning, word, officer, kind, divan, found
# Disgust	3	deserted, boy, interested
# Surprise	3	surprised, leave, suddenly
# Anticipation	3	thought, coming, planning
# Excitement	0
#
# Date Range: friday august 21 1942 to anne september 21 1942
# Joy	4	jump, helpful, nap, special
# Sadness	3	mad, dreadful, obnoxious
# Anger	5	spite, hot, mad, dreadful, obnoxious
# Fear	4	hiding, change, mad, dreadful
# Trust	3	father, secret, helpful
# Disgust	4	mad, boy, dreadful, obnoxious
# Surprise	0
# Anticipation	3	thought, start, dreadful
# Excitement	0
#
# Date Range: anne september 21 1942 to wednesday september 2 1942
# Joy	0
# Sadness	0
# Anger	0
# Fear	0
# Trust	0
# Disgust	0
# Surprise	0
# Anticipation	0
# Excitement	0
#
# Date Range: wednesday september 2 1942 to monday september 21 1942
# Joy	9	excellent, treasure, special, save, darling, friendly, mother, surprise, found
# Sadness	13	sullen, interested, leave, blue, falling, ill, hell, shell, napkin, wasting, wound, mother, worry
# Anger	13	fight, kicking, bear, sullen, friction, shock, ill, hell, shell, argument, wound, words, punishment
# Fear	17	harm, fight, difficult, bear, abominable, mum, shock, hiding, ill, shell, afraid, wasting, wound, hell, surprise, worry, punishment
# Trust	14	father, school, routine, excellent, treasure, save, darling, friendly, explain, account, mother, word, agreed, found
# Disgust	6	interested, abominable, ill, hell, wasting, punishment
# Surprise	7	catch, shock, shell, surprising, surprise, leave, suddenly
# Anticipation	10	thought, coming, long, treasure, friendly, happen, mother, immediately, worry, time
# Excitement	0
#
# Date Range: monday september 21 1942 to friday september 25 1942
# Joy	6	laugh, safe, tree, pretty, wonderful, food
# Sadness	4	ill, bottom, forgotten, unbearable
# Anger	4	ill, thump, tree, words
# Fear	3	ill, war, forgotten
# Trust	15	father, real, exchange, school, safe, tree, pretty, wonderful, wear, fact, general, series, food, divan, dictionary
# Disgust	4	ill, spoil, unbearable, tree
# Surprise	4	wonderful, laugh, trick, tree
# Anticipation	5	contingent, begun, tree, expecting, pretty
# Excitement	0
#
# Date Range: friday september 25 1942 to sunday september 27 1942
# Joy	11	laugh, fun, hilarity, amusing, love, prosperous, saintly, giggle, friend, mother, alive
# Sadness	2	pathetic, mother
# Anger	1	nuisance
# Fear	1	afraid
# Fear	10	dying, volunteer, awful, horrors, threatening, lines, force, ill, hide, horror
# Trust	9	money, ground, volunteer, frank, tree, finally, mother, diary, pretty
# Disgust	9	dying, awful, threatening, tree, finally, ill, sick, dislike, horror
# Surprise	5	money, slap, tree, finally, horror
# Anticipation	9	money, volunteer, coming, tree, finally, mother, thought, pretty, time
# Excitement	0
#
# Date Range: wednesday october 7 1942 to wednesday october 14 1942
# Joy	10	money, good, young, generous, humanity, wonderful, cream, diary, white, true
# Sadness	19	depressing, depart, horrors, death, fall, dismal, terrible, crippled, case, blue, impossible, ill, die, distraught, bad, prisoner, bomb, fatal, execution
# Anger	14	money, fatal, sneak, horrible, bad, death, prisoner, ill, grab, bomb, glaring, punishment, terrible, execution
# Fear	18	fatal, sneak, execution, horrors, die, horrible, case, bad, death, escape, prisoner, ill, hide, dismal, bomb, punishment, terrible, forced
# Trust	14	money, execution, good, school, leading, true, humanity, cap, wonderful, manage, generous, diary, white, innocent
# Disgust	10	depressing, horrible, bad, death, prisoner, ill, punishment, dismal, toilet, terrible
# Surprise	8	money, sneak, good, young, death, wonderful, cream, bomb
# Anticipation	13	money, daily, good, depart, young, cap, escape, death, await, cream, long, white, time
# Excitement	0
#
# Date Range: wednesday october 14 1942 to tuesday october 20 1942
# Joy	8	green, good, fun, progress, friendly, mother, diary, found
# Sadness	5	wretched, problem, awful, older, mother
# Anger	5	storm, lying, awful, furious, words
# Fear	4	mysterious, problem, awful, lines
# Trust	12	father, grammar, green, good, frank, friendly, fact, author, governess, mother, diary, found
# Disgust	5	wretched, lying, awful, ugly, furious
# Surprise	2	good, mysterious
# Anticipation	8	fun, good, mysterious, progress, friendly, mother, thought, time
# Excitement	0
#
# Date Range: tuesday october 20 1942 to thursday october 29 1942
# Joy	6	fun, delicious, wonderful, glad, white, kind
# Sadness	6	quiet, darkness, interrupted, unpleasant, dark, leave
# Anger	3	darkness, scare, fear
# Fear	8	fear, fire, stranger, hiding, darkness, warn, scare, shaking
# Trust	12	father, honor, fuse, fill, explain, wonderful, secret, usual, warn, white, kind, divan
# Disgust	1	unpleasant
# Surprise	5	leave, wonderful, warn, scare, suddenly
# Anticipation	9	fun, coming, long, scare, glad, warn, thought, white, time
# Excitement	0
#
# Date Range: thursday october 29 1942 to monday november 2 1942
# Joy	5	devout, good, lovely, mother, beautiful
# Sadness	8	groan, worried, abandon, leave, lovely, moan, mother, measles
# Anger	1	words
# Fear	6	hearing, abandon, moan, fever, measles, nervous
# Trust	8	father, devout, good, planning, fill, lovely, fairly, mother
# Disgust	2	groan, measles
# Surprise	3	lovely, leave, good
# Anticipation	9	devout, start, good, planning, tomorrow, lovely, mother, time, nervous
# Excitement	0
#
# Date Range: monday november 2 1942 to anne january 22 1944
# Joy	3	mother, fun, special
# Sadness	4	mother, crazy, bad, awful
# Anger	3	crazy, bad, awful
# Fear	3	crazy, bad, awful
# Trust	3	mother, frank, important
# Disgust	2	bad, awful
# Surprise	0
# Anticipation	5	start, fun, wait, long, mother
# Excitement	0
#
# Date Range: anne january 22 1944 to thursday november 5 1942
# Joy	6	love, affection, yearning, mother, diary, kind
# Sadness	2	mother, longing
# Anger	0
# Fear	1	change
# Trust	8	father, trust, affection, yearning, mother, diary, kind, innocent
# Disgust	0
# Surprise	0
# Anticipation	4	mother, yearning, time, longing
# Excitement	0
#
# Date Range: thursday november 5 1942 to saturday november 7 1942
# Joy	6	sweetheart, happy, finally, mother, success, special
# Sadness	3	mother, irritation, sweetheart
# Anger	1	irritation
# Fear	0
# Trust	6	sweetheart, frank, happy, finally, mother, word
# Disgust	2	irritation, finally
# Surprise	1	finally
# Anticipation	5	sweetheart, happy, finally, mother, success
# Excitement	0
#
# Date Range: saturday november 7 1942 to tuesday november 10 1942
# Joy	25	comfort, god, happy, clown, weight, satisfied, mother, baby, pay, true, jump, optimism, beautiful, good, present, affection, beauty, child, surprise, feeling, darling, laughter, diary, food, deal
# Sadness	19	falling, black, weight, mother, sarcasm, unable, ill, adrift, illness, broke, suffering, bottom, scold, cross, meaningless, feeling, despair, choke, ache
# Anger	16	choke, clash, contempt, feeling, vent, despair, carelessness, blame, ill, jealous, sarcasm, scold, attack, cross, injustice, confront
# Fear	16	flying, contempt, feeling, god, despair, ill, suffering, adrift, weight, broke, scold, stunned, attack, cross, surprise, illness
# Trust	27	comfort, god, happy, top, serve, weight, mother, pay, true, provide, optimism, advise, retain, good, present, intact, affection, secret, father, real, feeling, darling, deed, explain, diary, food, deal
# Disgust	11	contempt, feeling, despair, carelessness, blame, ill, suffering, jealous, weight, scold, sarcasm
# Surprise	12	feeling, good, clown, present, laughter, weight, optimism, differently, stunned, surprise, deal, judgment
# Anticipation	20	comfort, god, happy, clown, top, weight, patient, mother, pay, daily, coming, adrift, optimism, good, present, child, feeling, laughter, time, deal
# Excitement	0
#
# Date Range: tuesday november 10 1942 to thursday november 12 1942
# Joy	2	food, excellent
# Sadness	4	shell, worse, dreadful, quiet
# Anger	2	shell, dreadful
# Fear	6	worse, hiding, shell, afraid, dreadful, dangerous
# Trust	5	father, excellent, planning, fill, food
# Disgust	1	dreadful
# Surprise	1	shell
# Anticipation	4	thought, plan, dreadful, planning
# Excitement	0
#
# Date Range: thursday november 12 1942 to tuesday november 17 1942
# Joy	1	pleased
# Sadness	2	dark, delay
# Anger	1	delay
# Fear	2	hiding, delay
# Trust	2	father, accounts
# Disgust	1	delay
# Surprise	0
# Anticipation	4	long, arrive, thought, wait
# Excitement	0
#
# Date Range: tuesday november 17 1942 to thursday november 19 1942
# Joy	12	respect, advance, nap, music, civilized, classics, special, star, goodness, lovely, surprise, beautiful
# Sadness	8	unable, dispossessed, quiet, music, lovely, rumor, remove, owing
# Anger	4	vermin, remove, dispossessed, owing
# Fear	8	vermin, dispossessed, escape, advance, surprise, remove, suspense, owing
# Trust	13	frank, prepared, management, civilized, star, secret, goodness, guide, truth, lovely, officer, owing, respect
# Disgust	2	vermin, owing
# Surprise	5	advance, goodness, lovely, surprise, suspense
# Anticipation	19	track, escape, star, immediately, daily, coming, lovely, thought, expecting, goodness, await, advance, respect, prepared, owing, production, time, suspense, correspondence
# Excitement	0
#
# Date Range: thursday november 19 1942 to friday november 20 1942
# Joy	6	green, laugh, good, delighted, save, honest
# Sadness	12	worried, sacrifices, crying, death, hell, sick, turmoil, suffering, honest, gray, slave, exhaustion
# Anger	6	bully, death, hell, turmoil, honest, slave
# Fear	16	bully, sacrifices, lines, frightened, death, military, escape, hell, hiding, change, turmoil, suffering, wicked, honest, stalk, slave
# Trust	8	father, green, good, ground, save, fact, honest, innocent
# Disgust	8	sacrifices, death, hell, sick, suffering, honest, gray, toilet
# Surprise	8	laugh, catch, good, delighted, frightened, death, sudden, surprised
# Anticipation	10	thought, good, delighted, death, escape, immediately, long, fate, time, exhaustion
# Excitement	0
#
# Date Range: friday november 20 1942 to monday december 7 1942
# Joy	11	laughing, good, laugh, cheerful, feeling, young, finally, lucky, adore, mother, kind
# Sadness	18	deserted, misery, feeling, gloom, crying, badly, bad, scarcity, dark, cry, suffering, bottom, unhappy, dreadful, mother, crazy, gloomy, wanting
# Anger	12	deserted, misery, feeling, riot, react, scarcity, bad, teasing, unhappy, dreadful, crazy, ungrateful
# Fear	14	deserted, misery, harm, feeling, avoid, riot, react, scarcity, bad, teasing, taboo, suffering, dreadful, crazy
# Trust	18	father, advise, calls, feeling, good, personal, count, center, law, finally, account, secret, adore, economy, usual, mother, kind, continue
# Disgust	11	deserted, misery, feeling, bad, taboo, finally, suffering, unhappy, dreadful, gruesome, ungrateful
# Surprise	8	feeling, good, laugh, cheerful, young, finally, lucky, differently
# Anticipation	17	calls, recipient, start, good, feeling, long, young, begun, finally, attempt, result, adore, dreadful, mother, thought, time, continue
# Excitement	0
#
# Date Range: monday december 7 1942 to thursday december 10 1942
# Joy	8	money, fun, celebrated, good, wonderful, sing, gift, doll
# Sadness	3	black, sing, darkness
# Anger	2	money, darkness
# Fear	1	darkness
# Trust	6	father, money, good, cabinet, wonderful, sing
# Disgust	0
# Surprise	5	curiosity, money, good, wonderful, gift
# Anticipation	9	curiosity, money, fun, celebrated, good, sing, gift, long, time
# Excitement	0
#
# Date Range: thursday december 10 1942 to sunday december 13 1942
# Joy	9	fun, sunshine, laughter, finally, mother, food, found, deal, delight
# Sadness	13	wince, bothering, pain, case, concerned, bloody, broken, ill, victim, mother, rheumatism, remove, fat
# Anger	12	kicking, bothering, screaming, rheumatism, force, broken, ill, butcher, victim, wince, bloody, remove
# Fear	15	infection, screaming, pain, case, rheumatism, force, concerned, broken, ill, butcher, victim, wince, bloody, examination, remove
# Trust	7	ground, planning, finally, mother, food, deal, found
# Disgust	7	screaming, finally, ill, butcher, wince, bloody, fat
# Surprise	5	mouth, finally, laughter, examination, deal
# Anticipation	12	fun, coming, planning, audience, laughter, importance, finally, patient, mother, time, deal, delight
# Excitement	0
#
# Date Range: sunday december 13 1942 to tuesday december 22 1942
# Joy	3	green, food, feeling
# Sadness	4	feeling, grim, misfortune, fat
# Anger	4	politics, bark, feeling, grim
# Fear	5	rod, feeling, misfortune, change, grim
# Trust	5	rod, real, green, feeling, food
# Disgust	5	feeling, dirty, slum, grim, fat
# Surprise	2	feeling, trip
# Anticipation	4	tomorrow, neighborhood, feeling, grim
# Excitement	0
#
# Date Range: tuesday december 22 1942 to wednesday january 13 1943
# Joy	11	receiving, clean, good, cheerful, delighted, dawn, peace, lucky, glad, mother, kind
# Sadness	6	torment, black, ill, abandoned, mother, hanging
# Anger	8	revenge, lying, torment, pound, ill, disgusting, abandoned, hanging
# Fear	9	revenge, war, torment, government, hiding, ill, disgusting, abandoned, hanging
# Trust	8	clean, dawn, good, vigorous, peace, mother, constantly, kind
# Disgust	5	lying, egotistical, ill, disgusting, hanging
# Surprise	7	revenge, receiving, good, dawn, cheerful, delighted, lucky
# Anticipation	10	revenge, receiving, good, dawn, long, delighted, peace, glad, mother, time
# Excitement	0
#
# Date Range: wednesday january 13 1943 to saturday january 30 1943
# Joy	6	money, safe, cash, shopping, food, kind
# Sadness	9	helpless, bad, miserable, death, conflict, suffering, interrupted, terrible, beg
# Anger	9	money, fear, cash, selfish, bad, miserable, death, conflict, terrible
# Fear	9	war, fear, helpless, cash, bad, death, conflict, suffering, terrible
# Trust	9	money, school, safe, cash, fill, shopping, food, constantly, kind
# Disgust	7	bad, selfish, miserable, death, suffering, terrible, soil
# Surprise	3	money, death, shopping
# Anticipation	8	money, neighborhood, begun, cash, death, wait, shopping, time
# Excitement	0
#
# Date Range: saturday january 30 1943 to friday february 5 1943
# Joy	5	laugh, god, treat, mother, child
# Sadness	11	impossible, case, forgotten, cry, ill, treat, mocking, mother, leave, nasty, sympathy
# Anger	11	scream, rage, venomous, contempt, selfish, ill, treat, mocking, words, nasty, derision
# Fear	12	scream, contempt, venomous, cowardly, god, case, suspect, forgotten, ill, treat, nasty, shaking
# Trust	4	mother, god, father, treat
# Disgust	9	scream, contempt, venomous, selfish, ill, treat, mocking, nasty, derision
# Surprise	5	scream, laugh, treat, leave, suddenly
# Anticipation	5	long, god, treat, mother, child
# Excitement	0
#
# Date Range: friday february 5 1943 to saturday february 27 1943
# Joy	7	laughing, entertaining, laugh, hilarity, young, elegant, mother
# Sadness	6	danger, unable, quiet, misfortune, unpleasant, mother
# Anger	3	defense, words, tension
# Fear	5	danger, defense, misfortune, change, warn
# Trust	6	father, warn, fact, mother, mediate, sir
# Disgust	2	toilet, unpleasant
# Surprise	3	young, laugh, warn
# Anticipation	9	defense, entertaining, thought, long, young, wait, warn, mother, mediate
# Excitement	0
#
# Date Range: saturday february 27 1943 to thursday march 4 1943
# Joy	5	champion, good, goodness, freedom, beautiful
# Sadness	3	late, case, unfair
# Anger	5	fight, argument, words, unfair, invasion
# Fear	4	case, fight, afraid, pneumonia
# Trust	9	champion, father, good, secret, goodness, author, episcopal, freedom, fellow
# Disgust	2	brothel, unfair
# Surprise	3	guess, goodness, good
# Anticipation	5	champion, letter, good, expecting, goodness
# Excitement	0
#
# Date Range: thursday march 4 1943 to wednesday march 10 1943
# Joy	5	money, good, food, pay, silly
# Sadness	2	black, sick
# Anger	5	money, brimstone, bombardment, words, ridiculous
# Fear	5	brimstone, fire, hiding, bombardment, afraid
# Trust	8	money, father, good, ground, agreement, food, explain, pay
# Disgust	4	sneeze, cough, sick, ridiculous
# Surprise	3	money, sneeze, good
# Anticipation	6	money, good, coming, long, thought, pay
# Excitement	0
#
# Date Range: wednesday march 10 1943 to friday march 12 1943
# Joy	6	dawn, fun, comfort, safe, mother, white
# Sadness	9	awful, pain, impossible, bad, worse, uninvited, dark, fell, mother
# Anger	6	fear, awful, annoyance, bad, shock, shooting
# Fear	12	fear, awful, rat, fire, pain, frightened, bad, worse, shock, afraid, ghostly, shooting
# Trust	7	father, dawn, comfort, safe, secret, mother, white
# Disgust	4	annoyance, bad, awful, rat
# Surprise	4	shock, frightened, dawn, suddenly
# Anticipation	8	dawn, fun, comfort, wait, mother, thought, white, time
# Excitement	0
#
# Date Range: friday march 12 1943 to thursday march 18 1943
# Joy	8	good, cheerful, emancipation, amuse, victor, honest, mother, food
# Sadness	8	worn, black, sick, shortage, hell, honest, mother, terrible
# Anger	6	aggressor, politics, shortage, hell, honest, terrible
# Fear	7	war, aggressor, hiding, shortage, hell, honest, terrible
# Trust	6	good, frank, fact, honest, mother, food
# Disgust	4	hell, sick, terrible, honest
# Surprise	2	good, cheerful
# Anticipation	6	good, start, emancipation, mother, ultimately, time
# Excitement	0
#
# Date Range: thursday march 18 1943 to friday march 19 1943
# Joy	1	excitement
# Sadness	0
# Anger	0
# Fear	1	war
# Trust	0
# Disgust	0
# Surprise	1	excitement
# Anticipation	1	excitement
# Excitement	0
#
# Date Range: friday march 19 1943 to thursday march 25 1943
# Joy	6	money, compensate, joy, proud, pay, kind
# Sadness	13	disappoint, invalid, inferior, missing, terribly, lax, black, ill, pathetic, damages, wound, rumor, hideous
# Anger	4	money, disappoint, ill, wound
# Fear	7	war, missing, hiding, ill, wound, shaking, hideous
# Trust	10	money, provide, father, compensate, proud, show, proof, pay, teacher, kind
# Disgust	4	ill, disappoint, pathetic, hideous
# Surprise	2	money, compensate
# Anticipation	9	money, compensate, coming, proud, long, thought, pay, time, correspondence
# Excitement	0
#
# Date Range: thursday march 25 1943 to saturday march 27 1943
# Joy	8	pleasant, laugh, safe, finally, excitement, mother, white, found
# Sadness	6	danger, problem, quiet, falling, mother, mistake
# Anger	4	armed, kicking, tension, words
# Fear	11	danger, cautiously, problem, burglar, armed, suspense, police, jeopardy, warn, nervous, forced
# Trust	13	father, pleasant, safe, police, finally, warn, account, expect, fact, mother, white, agreed, found
# Disgust	5	burglar, excrement, finally, cough, toilet
# Surprise	9	incident, pleasant, laugh, finally, expect, excitement, warn, suspense, suddenly
# Anticipation	15	pleasant, thought, begun, suspense, finally, warn, importance, expect, jeopardy, excitement, mother, immediately, white, time, nervous
# Excitement	0
#
# Date Range: saturday march 27 1943 to thursday april 1 1943
# Joy	4	labor, good, fancy, appreciation
# Sadness	4	ill, sick, sabotage, neglected
# Anger	3	ill, sabotage, neglected
# Fear	4	ill, sabotage, fire, police
# Trust	8	exchange, good, labor, appreciation, important, top, police, county
# Disgust	5	sabotage, neglected, ill, sick, nose
# Surprise	4	labor, sabotage, good, mouth
# Anticipation	5	good, labor, top, fancy, time
# Excitement	0
#
# Date Range: thursday april 1 1943 to friday april 2 1943
# Joy	2	merry, sunshine
# Sadness	8	bothering, lie, surgery, agony, ulcer, hospital, fell, forgotten
# Anger	6	bout, fear, bothering, lie, agony, ulcer
# Fear	8	fear, surgery, agony, ulcer, hospital, flu, forgotten, shaking
# Trust	5	father, important, hospital, word, continue
# Disgust	3	ulcer, stomach, lie
# Surprise	1	quote
# Anticipation	4	thought, time, quote, continue
# Excitement	0
#
# Date Range: friday april 2 1943 to tuesday april 27 1943
# Joy	4	mother, love, feeling, pray
# Sadness	11	feeling, cross, coldness, pain, cruel, unkind, reject, mother, sorrow, apologize, shrink
# Anger	10	feeling, lying, cruel, unkind, reject, angry, words, coldness, cross, cruelly
# Fear	11	feeling, cross, pray, pain, cruel, unkind, reject, coldness, sorrow, shrink, cruelly
# Trust	8	father, dare, feeling, pray, truth, mother, apologize, continue
# Disgust	6	feeling, lying, cruel, unkind, angry, coldness
# Surprise	3	feeling, pray, suddenly
# Anticipation	7	dare, feeling, pray, happen, mother, time, continue
# Excitement	0
#
# Date Range: tuesday april 27 1943 to saturday may 1 1943
# Joy	3	mother, food, good
# Sadness	9	beating, complain, bitterly, terrible, mad, bleeding, mother, destroyed, terrific
# Anger	7	invasion, beating, complain, bitterly, mad, terrible, destroyed
# Fear	7	trembling, beating, fire, terrible, mad, bleeding, destroyed
# Trust	6	father, good, top, mother, food, county
# Disgust	5	stomach, bitterly, mad, bleeding, terrible
# Surprise	1	good
# Anticipation	6	daily, neighborhood, good, long, top, mother
# Excitement	0
#
# Date Range: saturday may 1 1943 to sunday may 2 1943
# Joy	8	respect, excited, save, darling, chocolate, shopping, silly, found
# Sadness	4	stingy, sick, badly, case
# Anger	4	stingy, martial, destruction, disgraceful
# Fear	3	stingy, case, flee
# Trust	8	respect, excited, save, darling, law, chocolate, shopping, found
# Disgust	5	stomach, stingy, sick, sticky, disgraceful
# Surprise	2	excited, shopping
# Anticipation	5	excited, chocolate, shopping, time, respect
# Excitement	0
#
# Date Range: sunday may 2 1943 to sunday may 2 1943
# Joy	4	mother, clean, hope, respect
# Sadness	5	sunk, worn, ill, mother, frayed
# Anger	2	ill, possession
# Fear	5	war, sunk, hiding, ill, possession
# Trust	8	father, respect, clean, cover, spotless, mother, hope, wear
# Disgust	4	ill, sunk, possession, stomach
# Surprise	1	hope
# Anticipation	4	long, hope, mother, respect
# Excitement	0
#
# Date Range: sunday may 2 1943 to tuesday may 18 1943
# Joy	7	money, good, clean, beautiful, mother, hope, respect
# Sadness	8	doubt, pain, sunk, worn, ill, mother, sorrow, frayed
# Anger	8	money, fear, contradict, ill, politics, possession, tension, ridiculous
# Fear	12	doubt, war, fear, pain, sunk, hiding, ill, hide, afraid, possession, sorrow, forced
# Trust	21	money, doubt, clean, law, account, mother, frank, count, gentleman, good, cover, word, hope, respect, father, optimist, wear, majesty, assure, spotless, general
# Disgust	5	stomach, sunk, ill, possession, ridiculous
# Surprise	4	money, good, hope, surprising
# Anticipation	9	money, good, expectation, mother, long, immediately, time, hope, respect
# Excitement	0
#
# Date Range: tuesday may 18 1943 to sunday june 13 1943
# Joy	11	jump, spouse, labor, comfort, glow, welcomed, laughter, mother, youth, approve, child
# Sadness	7	unable, trash, sympathize, death, injured, mother, penalty
# Anger	7	hot, death, carelessness, words, shooting, youth, penalty
# Fear	7	death, injured, obey, police, shooting, youth, penalty
# Trust	14	pilot, crew, official, conscience, spouse, labor, statement, glow, comfort, mother, obey, police, allied, approve
# Disgust	4	garbage, death, carelessness, trash
# Surprise	5	labor, death, laughter, youth, suddenly
# Anticipation	10	labor, comfort, glow, seek, death, laughter, mother, thought, youth, child
# Excitement	0
#
# Date Range: sunday june 13 1943 to tuesday june 15 1943
# Joy	7	peace, treat, proud, favorite, birthday, lovely, food
# Sadness	6	dispel, boredom, plight, treat, wasting, lovely
# Anger	2	treat, bear
# Fear	5	difficult, bear, plight, treat, wasting
# Trust	10	father, pill, peace, treat, proud, favorite, usual, lovely, food, wear
# Disgust	3	treat, wasting, plight
# Surprise	3	treat, lovely, birthday
# Anticipation	7	plight, peace, treat, proud, birthday, lovely, time
# Excitement	0
#
# Date Range: tuesday june 15 1943 to sunday july 11 1943
# Joy	7	money, good, cheer, spirits, baby, grow, beautiful
# Sadness	11	death, hate, worse, pointless, ill, ulcer, dreary, cancer, lose, error, hospital
# Anger	7	money, death, hate, lose, cancer, ill, ulcer
# Fear	10	operation, death, hate, worse, cancer, ill, ulcer, hiding, lose, hospital
# Trust	7	money, good, cheer, operation, cabinet, hospital, grow
# Disgust	6	death, hate, lose, cancer, ill, ulcer
# Surprise	6	money, good, cheer, lose, death, spirits
# Anticipation	8	money, good, cheer, approaching, death, store, spirits, grow
# Excitement	0
#
# Date Range: sunday july 11 1943 to tuesday july 13 1943
# Joy	11	remarkable, friendly, mother, shopping, humorous, glad, child, deal, kind, approve, helpful
# Sadness	6	unable, impossible, difficulties, gray, unfair, mother
# Anger	3	unfair, anger, mule
# Fear	2	hiding, hearing
# Trust	11	important, remarkable, weigh, friendly, shopping, mother, deal, mule, kind, approve, helpful
# Disgust	3	unfair, sour, gray
# Surprise	3	remarkable, deal, shopping
# Anticipation	12	long, weigh, friendly, mother, immediately, ready, glad, shopping, child, thought, time, deal
# Excitement	0
#
# Date Range: tuesday july 13 1943 to friday july 16 1943
# Joy	7	good, smile, triumph, kind, finally, food, deal
# Sadness	7	sullen, upset, pointless, ill, mug, hell, refused
# Anger	11	smack, intruder, rage, sullen, upset, contradict, ill, mug, hell, wrath, words
# Fear	6	intruder, ill, mug, hell, wrath, change
# Trust	14	father, good, frank, smile, advice, prepared, finally, kind, agreed, fairly, elder, doctor, food, deal
# Disgust	4	ill, finally, hell, ugly
# Surprise	5	intruder, good, smile, finally, deal
# Anticipation	10	good, prepared, wait, triumph, finally, opportunity, long, thought, time, deal
# Excitement	0
#
# Date Range: friday july 16 1943 to friday july 23 1943
# Joy	5	cash, excitement, glad, luck, deal
# Sadness	4	dull, shiver, quiet, unsuccessful
# Anger	5	gang, cash, destruction, shiver, indignant
# Fear	6	gang, burglar, forced, cash, shiver, stealing
# Trust	3	cash, deal, usual
# Disgust	3	bombed, stealing, burglar
# Surprise	3	luck, excitement, deal
# Anticipation	11	letter, cash, approaching, attempt, excitement, glad, shiver, luck, immediately, time, deal
# Excitement	0
#
# Date Range: friday july 23 1943 to monday july 26 1943
# Joy	4	mother, fun, overjoyed, freely
# Sadness	6	dying, worthless, lie, gray, mother, fat
# Anger	5	dying, spite, worthless, lie, words
# Fear	4	hiding, lines, dying, homework
# Trust	7	father, real, school, bargain, mother, advised, freely
# Disgust	5	dying, worthless, lie, gray, fat
# Surprise	0
# Anticipation	3	long, fun, mother
# Excitement	0
#
# Date Range: monday july 26 1943 to thursday july 29 1943
# Joy	10	good, joy, peace, finally, wonderful, hope, excitement, food, kind, rising
# Sadness	7	shot, awful, stroke, falling, resigned, wound, fell
# Anger	8	shot, awful, stolen, hit, raid, tumultuous, wound, smell
# Fear	18	siren, shot, war, flying, warning, awful, fire, alarm, stroke, escape, government, suspense, raid, shaking, tumultuous, wound, watch, dangerous
# Trust	10	father, good, peace, assure, finally, wonderful, hope, harbor, food, kind
# Disgust	4	bombed, smell, awful, finally
# Surprise	9	shot, good, alarm, suspense, finally, wonderful, raid, excitement, hope
# Anticipation	14	good, airport, coming, peace, escape, suspense, finally, excitement, long, watch, thought, time, hope, rising
# Excitement	0
#
# Date Range: thursday july 29 1943 to tuesday august 3 1943
# Joy	8	good, fun, enjoy, young, love, excellent, friendly, mother
# Sadness	7	unimportant, unable, quiet, bad, fall, older, mother
# Anger	6	rage, bad, disagree, despicable, words, tirade
# Fear	4	prejudiced, difficult, bad, avoid
# Trust	7	recommend, good, enjoy, excellent, friendly, theory, mother
# Disgust	7	boy, egotistical, bad, ugly, despicable, prejudiced, tirade
# Surprise	3	young, good, catch
# Anticipation	10	good, fun, enjoy, young, long, friendly, theory, hurry, mother, thought
# Excitement	0
#
# Date Range: tuesday august 3 1943 to thursday august 5 1943
# Joy	8	fun, food, safe, perfect, birthday, white, deal, beautiful
# Sadness	13	quiet, case, bomb, worse, fall, ill, black, broken, dark, lower, fell, remove, strip
# Anger	15	fight, spat, hot, shrill, suspicious, politics, raid, ill, broken, angry, fighting, bomb, shooting, remove, ridiculous
# Fear	17	fight, war, courageous, cowardly, case, alarm, shrill, worse, hiding, raid, ill, broken, gasping, bomb, shooting, remove, shaking
# Trust	15	father, dare, real, calls, majesty, larger, safe, white, grit, perfect, harbor, food, deal, divan, continue
# Disgust	7	larger, ill, indecent, angry, flea, unsightly, ridiculous
# Surprise	9	larger, exclaim, alarm, shrill, raid, birthday, bomb, occasional, deal
# Anticipation	14	dare, calls, start, fun, clock, suspicious, opportunity, perfect, birthday, long, white, time, deal, continue
# Excitement	0
#
# Date Range: thursday august 5 1943 to saturday august 7 1943
# Joy	6	excellent, peace, companion, mother, glee, food
# Sadness	4	mother, late, quiet, missing
# Anger	1	gang
# Fear	4	homework, gang, shady, missing
# Trust	8	father, excellent, peace, companion, constant, mother, food, divan
# Disgust	0
# Surprise	1	break
# Anticipation	5	long, peace, clock, mother, time
# Excitement	0
#
# Date Range: saturday august 7 1943 to monday august 9 1943
# Joy	0
# Sadness	0
# Anger	0
# Fear	0
# Trust	0
# Disgust	0
# Surprise	0
# Anticipation	0
# Excitement	0
#
# Date Range: monday august 9 1943 to tuesday august 10 1943
# Joy	12	fun, good, cheerful, smile, young, nap, favorite, goodness, share, mother, food, kind
# Sadness	9	quiet, interested, case, bad, concerned, black, interrupted, mother, guilty
# Anger	4	fight, bad, guilty, hiss
# Fear	6	fight, hiss, case, bad, concerned, watch
# Trust	16	father, calls, good, modest, frank, smile, advice, favorite, goodness, share, mother, suggest, word, food, kind, continue
# Disgust	2	bad, interested
# Surprise	5	good, cheerful, smile, young, goodness
# Anticipation	10	calls, fun, good, young, goodness, share, long, watch, mother, continue
# Excitement	0
#
# Date Range: tuesday august 10 1943 to monday august 23 1943
# Joy	15	sweetheart, art, heavenly, good, accomplished, comfort, pleased, achieve, favorite, freedom, glad, mother, luck, white, beautiful
# Sadness	19	danger, doubt, hurt, quiet, mother, leave, impossible, case, unlucky, worse, ill, sweetheart, art, crying, bad, bottom, lost, blunder, bomb
# Anger	9	fight, bad, unlucky, bomb, ill, angry, hurt, invasion, tirade
# Fear	16	danger, war, doubt, fight, avoid, bait, case, escaped, bad, unlucky, worse, bomb, ill, change, tactics, hurt
# Trust	19	doubt, heavenly, comfort, cabinet, top, mother, continue, frank, bait, agreement, achieve, freedom, white, sweetheart, good, father, calls, favorite, tactics
# Disgust	8	bad, unlucky, ill, dirty, gutter, angry, blunder, tirade
# Surprise	6	art, luck, good, bomb, leave, slip
# Anticipation	18	sweetheart, art, calls, neighborhood, good, heavenly, daily, comfort, tomorrow, top, glad, clock, mother, luck, thought, white, time, continue
# Excitement	0
#
# Date Range: monday august 23 1943 to friday september 10 1943
# Joy	2	mother, good
# Sadness	5	quiet, disappointed, stroke, mother, die
# Anger	2	shove, disappointed
# Fear	3	stroke, die, nervous
# Trust	6	father, good, top, manage, mother, dictionary
# Disgust	2	toilet, disappointed
# Surprise	2	good, suddenly
# Anticipation	8	good, long, forming, top, clock, mother, time, nervous
# Excitement	0
#
# Date Range: friday september 10 1943 to thursday september 16 1943
# Joy	12	pleasant, cheerful, god, amazingly, save, wonderful, raving, mother, truce, special, sun, delight
# Sadness	6	pain, sick, treachery, unpleasant, hospital, mother
# Anger	2	treachery, raving
# Fear	8	war, difficult, pain, god, operation, treachery, hospital, raving
# Trust	11	pleasant, god, operation, save, wonderful, errand, fact, hospital, mother, truce, sun
# Disgust	3	sick, stomach, unpleasant
# Surprise	7	pleasant, cheerful, amazingly, wonderful, treachery, raving, sun
# Anticipation	10	daily, pleasant, god, errand, sun, raving, mother, time, announcement, delight
# Excitement	0
#
# Date Range: thursday september 16 1943 to wednesday september 29 1943
# Joy	4	possess, food, laugh, brighten
# Sadness	10	sorrow, touchy, miserable, anxiety, worse, wound, depression, leave, forgotten, die
# Anger	7	fight, touchy, miserable, anxiety, suspicious, wound, resent
# Fear	12	warned, fight, sag, terror, avoid, cautious, anxiety, worse, wound, sorrow, forgotten, die
# Trust	7	possess, cautious, fact, brighten, negotiate, food, unreliable
# Disgust	1	miserable
# Surprise	7	curiosity, warned, laugh, mouth, brighten, leave, slip
# Anticipation	8	curiosity, warned, possess, cautious, anxiety, suspicious, thought, time
# Excitement	0
#
# Date Range: wednesday september 29 1943 to sunday october 17 1943
# Joy	6	friendly, sweet, shopping, mother, food, kind
# Sadness	6	disappointed, sick, mother, crazy, leave, shrink
# Anger	5	disappointed, annoyance, argument, crazy, deserve
# Fear	2	crazy, shrink
# Trust	10	father, accord, deserve, usual, friendly, sweet, shopping, mother, food, kind
# Disgust	3	sick, annoyance, disappointed
# Surprise	3	leave, sweet, shopping
# Anticipation	6	friendly, sweet, shopping, mother, deserve, time
# Excitement	0
#
# Date Range: sunday october 17 1943 to wednesday november 3 1943
# Joy	9	money, darling, laughter, lucky, goodness, sweet, mother, pay, reconciliation
# Sadness	21	problem, oppressive, awful, thief, sluggish, kill, mother, dark, terrible, unable, case, hell, bleeding, cage, lie, crying, miserable, broke, shortage, bottom, lost
# Anger	17	money, fear, oppressive, row, awful, screaming, lie, raging, thief, stolen, miserable, hell, shortage, profanity, bickering, tension, terrible
# ...
# Joy	4	tenderness, love, happy, kiss
# Sadness	2	ill, hell
# Anger	4	ill, conquest, force, hell
# Fear	4	ill, conquest, force, hell
# Trust	2	happy, frank
# Disgust	3	ill, boy, hell
# Surprise	1	kiss
# Anticipation	2	happy, kiss
# Excitement	0
#
# Date Range: saturday may 20 1944 to thursday may 25 1944
# Joy	18	heroic, laughing, laugh, good, true, faith, save, liberation, freedom, honest, generous, lovely, luck, hope, pay, mother, rising, beautiful
# Sadness	21	dismay, awful, mother, sorrow, terrible, ruined, affront, sacrifices, damage, impossible, upset, lovely, die, hatred, crying, bad, honest, loss, lost, dreadful, unfortunate
# Anger	20	dismay, awful, unjust, deserve, ruined, terrible, affront, threat, damage, upset, fighting, words, hatred, invasion, bad, honest, unthinkable, loss, blame, dreadful
# Fear	24	dismay, asylum, difficult, awful, mistaken, fever, sorrow, ruined, terrible, affront, threat, sacrifices, waver, die, hatred, bad, honest, unthinkable, war, loss, dreadful, foreboding, suspense, anxious
# Trust	25	heroic, save, confirmed, fact, mother, deserve, pay, shoulder, true, frank, show, truth, generous, lovely, freedom, good, cover, justice, honest, hope, father, policy, upright, expect, faith
# Disgust	14	affront, sacrifices, awful, damage, lesser, bad, blame, dreadful, nose, honest, unthinkable, ruined, terrible, hatred
# Surprise	14	heroic, affront, dismay, laugh, purity, good, expect, liberation, hope, differently, lovely, luck, suspense, judgment
# Anticipation	19	dismay, mother, fate, pay, deserve, lovely, good, liberation, long, hope, expect, dreadful, foreboding, faith, luck, time, suspense, rising, anxious
# Excitement	0
#
# Date Range: thursday may 25 1944 to friday may 26 1944
# Joy	6	young, happy, pleased, hope, mother, deal
# Sadness	10	lowest, case, loss, worse, loneliness, lonely, abyss, black, ill, mother
# Anger	4	lonely, ill, loss, hot
# Fear	10	rule, war, case, loss, worse, loneliness, hiding, abyss, lonely, ill
# Trust	10	advise, father, rule, frank, steady, happy, agreeable, hope, mother, deal
# Disgust	2	lonely, ill
# Surprise	4	young, hope, deal, steady
# Anticipation	7	young, happy, hope, happen, mother, deal, hungry
# Excitement	0
#
# Date Range: friday may 26 1944 to wednesday may 31 1944
# Joy	6	laugh, good, love, happy, weight, food
# Sadness	15	misery, oppressive, awful, disappointment, cruel, miserable, despair, forgotten, anxiety, broken, weight, mocking, horror, shrink, unbearable
# Anger	16	misery, fear, oppressive, awful, bear, cruel, miserable, despair, anxiety, broken, raid, mocking, crushing, tension, horror, invasion
# Fear	21	misery, oppressive, awful, cruel, weight, stunned, forgotten, shrink, fear, bear, mysterious, broken, hiding, raid, police, anxiety, crushing, horror, forced, frightened, despair
# Trust	9	father, noble, good, frank, happy, top, weight, police, food
# Disgust	14	misery, oppressive, awful, disappointment, cruel, miserable, despair, dirty, crushing, weight, mocking, horror, toilet, unbearable
# Surprise	8	laugh, good, mysterious, frightened, raid, weight, stunned, horror
# Anticipation	11	good, coming, mysterious, happy, top, anxiety, weight, happen, hurry, long, thought
# Excitement	0
#
# Date Range: wednesday may 31 1944 to friday june 2 1944
# Joy	5	finally, wonderful, shining, enjoying, beautiful
# Sadness	5	awful, late, ill, hurt, suffocating
# Anger	5	awful, hot, horrible, ill, hurt
# Fear	5	awful, horrible, ill, hurt, suffocating
# Trust	8	frank, enjoying, watchman, finally, fixed, wonderful, word, wear
# Disgust	6	awful, horrible, finally, ill, sour, suffocating
# Surprise	2	wonderful, finally
# Anticipation	3	enjoying, shining, finally
# Excitement	0
#
# Date Range: friday june 2 1944 to monday june 5 1944
# Joy	3	safe, success, good
# Sadness	4	worry, problem, worse, falling
# Anger	2	shooting, fear
# Fear	6	fear, problem, worse, hiding, shooting, worry
# Trust	4	safe, formula, good, frank
# Disgust	0
# Surprise	1	good
# Anticipation	3	worry, good, success
# Excitement	0
#
# Date Range: monday june 5 1944 to tuesday june 6 1944
# Joy	2	friendship, friendly
# Sadness	5	impossible, bad, black, bottom, destroyed
# Anger	2	bad, destroyed
# Fear	2	bad, destroyed
# Trust	3	friendship, frank, friendly
# Disgust	2	bad, bombed
# Surprise	0
# Anticipation	2	long, friendly
# Excitement	0
#
# Date Range: tuesday june 6 1944 to friday june 9 1944
# Joy	9	feeling, good, victory, engaged, liberation, salvation, luck, hope, true
# Sadness	10	feeling, agony, bad, cry, ill, suffering, dark, bomb, terrible, destroyed
# Anger	13	combat, commotion, feeling, agony, bad, hit, ill, fighting, enemy, bomb, destroyed, terrible, invasion
# Fear	12	warned, combat, feeling, lines, agony, bad, ill, suffering, enemy, bomb, terrible, destroyed
# Trust	15	real, feeling, good, school, frank, ground, victory, engaged, steadfast, general, salvation, measure, usual, hope, true
# Disgust	6	feeling, bad, ill, suffering, enemy, terrible
# Surprise	7	warned, feeling, good, bomb, liberation, luck, hope
# Anticipation	14	warned, feeling, good, prepare, begun, victory, engaged, liberation, salvation, long, luck, thought, time, hope
# Excitement	0
#
# Date Range: friday june 9 1944 to tuesday june 13 1944
# Joy	9	money, art, music, finally, victor, excitement, generous, child, freedom
# Sadness	7	art, music, bad, miserable, difficulties, crazy, unbearable
# Anger	6	money, bad, miserable, fighting, crazy, invasion
# Fear	4	flying, war, bad, crazy
# Trust	6	money, modest, frank, finally, generous, freedom
# Disgust	4	bad, miserable, unbearable, finally
# Surprise	4	money, art, excitement, finally
# Anticipation	6	money, art, finally, excitement, child, time
# Excitement	0
#
# Date Range: tuesday june 13 1944 to friday june 16 1944
# Joy	31	comfort, enjoy, admiration, mother, hopeful, true, found, bouquet, esteem, progress, finally, starry, glad, birthday, beautiful, birth, art, good, present, affection, liberate, sweet, holiday, beauty, kind, respect, hero, favorite, share, luck, reward
# Sadness	27	doubt, misery, dark, mother, remove, leave, terrible, esteem, isolated, blue, hate, illness, art, miserable, humble, buried, sentence, unfair, cross, curse, tolerate, pain, rainy, longing, crazy, inferior, struggle
# Anger	29	misery, glare, quarrel, remove, terrible, fear, bear, hate, scoff, dislike, words, injustice, invasion, complaint, miserable, liberate, accused, sentence, unfair, cross, curse, fight, spite, tolerate, arrogant, hot, force, crazy, struggle
# Fear	29	doubt, misery, difficult, glare, hide, remove, terrible, fear, isolated, mysterious, courageous, bear, government, hate, change, illness, shaking, birth, buried, accused, sentence, cross, curse, fight, war, pain, force, crazy, struggle
# Trust	38	doubt, comfort, enjoy, strength, fact, admiration, mother, hopeful, true, found, bouquet, religion, esteem, frank, agreement, confide, finally, system, truth, author, birth, good, advice, fort, present, affection, liberate, sweet, kind, respect, father, real, hero, favorite, theory, share, convinced, reward
# Disgust	15	misery, boy, arrogant, miserable, hate, humble, finally, scoff, dislike, abject, sentence, pompous, unfair, terrible, curse
# Surprise	13	art, good, mysterious, leave, hero, present, finally, liberate, sweet, birthday, luck, hopeful, reward
# Anticipation	33	comfort, enjoy, ready, mother, hopeful, mysterious, progress, finally, opportunity, starry, glad, birthday, thought, ultimately, birth, art, good, intended, present, liberate, sweet, sentence, holiday, long, respect, start, hero, longing, theory, share, luck, time, reward
# Excitement	0
#
# Date Range: friday june 16 1944 to friday june 23 1944
# Joy	4	money, humanity, laugh, mother
# Sadness	7	shot, offended, worse, suicide, prison, suffering, mother
# Anger	6	shot, money, irritable, offended, suicide, prison
# Fear	7	shot, rule, worse, suicide, prison, suffering, afraid
# Trust	6	money, rule, frank, humanity, strength, mother
# Disgust	3	suffering, stomach, egotistical
# Surprise	3	shot, laugh, money
# Anticipation	2	money, mother
# Excitement	0
#
# Date Range: friday june 23 1944 to tuesday june 27 1944
# Joy	2	vacation, special
# Sadness	2	sunk, lower
# Anger	2	attack, offensive
# Fear	3	attack, sunk, operation
# Trust	3	count, operation, frank
# Disgust	2	sunk, offensive
# Surprise	0
# Anticipation	2	begun, vacation
# Excitement	0
#
# Date Range: tuesday june 27 1944 to friday june 30 1944
# Joy	1	luck
# Sadness	8	captive, damage, socialist, bad, hell, broken, fell, fat
# Anger	8	fight, screaming, damage, socialist, bad, hell, broken, invasion
# Surprise	17	feeling, laugh, good, young, worm, outrageous, lose, death, finally, mouth, shell, sweet, excitement, differently, break, leave, deal
# Anticipation	35	letter, young, god, top, death, impatient, triumph, excitement, mail, mother, grow, intimate, coming, peace, worm, finally, morn, glad, hurried, ultimately, auction, good, withstand, contingent, store, sweet, child, grim, feeling, start, approaching, share, watch, time, deal
# Excitement	0
#
# Date Range: friday july 21 1944 to tuesday august 1 1944
# Joy	5	young, peace, happy, loyal, kind
# Sadness	8	shot, assassination, sore, death, hell, kill, soldier, dictatorship
# Anger	10	shot, rifle, assassination, sore, soldier, death, hell, shoot, dictatorship, reprimand
# Fear	13	shot, war, rifle, cowardly, assassination, escaped, death, loyal, hell, kill, shoot, dictatorship, conspiracy
# Trust	13	commanding, school, frank, peace, establish, happy, loyal, kind, general, truth, proof, officer, impeccable
# Disgust	3	hell, dictatorship, death
# Surprise	4	young, shot, death, loyal
# Anticipation	8	start, peace, young, happy, death, attempt, dictatorship, time
# Excitement	0
#
# Date Range: tuesday august 1 1944 to morning august 4 1944
# Joy	11	powerful, good, joy, amusing, happy, clown, save, finally, embrace, honest, cheerfulness
# Sadness	11	quiet, bad, ill, sick, mocking, unpleasant, honest, cross, forgotten, negative, steal
# Anger	12	powerful, lying, ambush, bad, ill, mocking, dislike, honest, words, enemy, cross, steal
# Fear	11	powerful, cross, ambush, bad, ill, change, honest, enemy, hide, forgotten, steal
# Trust	12	powerful, good, frank, advice, happy, save, finally, secret, embrace, honest, word, cheerfulness
# Disgust	11	powerful, lying, bad, finally, ill, sick, mocking, dislike, honest, unpleasant, enemy
# Surprise	6	good, ambush, clown, finally, embrace, diversion
# Anticipation	9	letter, powerful, good, happy, clown, wait, finally, embrace, cheerfulness
# Excitement	0
#
# Date Range: morning august 4 1944 to amsterdam september 11 1944
# Joy	2	cash, victor
# Sadness	0
# Anger	2	armed, cash
# Fear	4	police, cash, hiding, armed
# Trust	2	police, cash
# Disgust	0
# Surprise	0
# Anticipation	1	cash
# Excitement	0
#
# Date Range: amsterdam september 11 1944 to released september 18 1944
# Joy	0
# Sadness	0
# Anger	0
# Fear	0
# Trust	0
# Disgust	0
# Surprise	0
# Anticipation	0
# Excitement	0
#
# Date Range: released september 18 1944 to imprisonment march 28 1945
# Joy	0
# Sadness	1	death
# Anger	1	death
# Fear	2	death, escape
# Trust	0
# Disgust	1	death
# Surprise	1	death
# Anticipation	2	death, escape
# Excitement	0
#
# Date Range: imprisonment march 28 1945 to deported september 3 1944
# Joy	0
# Sadness	0
# Anger	0
# Fear	1	forced
# Trust	1	fellow
# Disgust	0
# Surprise	0
# Anticipation	0
# Excitement	0
#
# Date Range: deported september 3 1944 to theresienstadt april 9 1945
# Joy	0
# Sadness	2	leave, death
# Anger	1	death
# Fear	1	death
# Trust	2	testimony, frank
# Disgust	1	death
# Surprise	2	leave, death
# Anticipation	2	shortly, death
# Excitement	0
#
# Date Range: theresienstadt april 9 1945 to part january 16 1945
# Joy	0
# Sadness	1	death
# Anger	1	death
# Fear	3	unknown, death, forced
# Trust	0
# Disgust	1	death
# Surprise	1	death
# Anticipation	2	unknown, death
# Excitement	0
#
# Date Range: part january 16 1945 to died may 5 1945
# Joy	0
# Sadness	1	death
# Anger	1	death
# Fear	1	death
# Trust	0
# Disgust	1	death
# Surprise	1	death
# Anticipation	1	death
# Excitement	0
#
# Date Range: died may 5 1945 to died december 20 1944
# Joy	0
# Sadness	0
# Anger	0
# Fear	0
# Trust	0
# Disgust	0
# Surprise	0
# Anticipation	0
# Excitement	0
#
# Date Range: died december 20 1944 to auschwitzbirkenau january 6 1945
# Joy	0
# Sadness	0
# Anger	0
# Fear	0
# Trust	1	frank
# Disgust	0
# Surprise	0
# Anticipation	0
# Excitement	0
#
# Date Range: auschwitzbirkenau january 6 1945 to troops april 12 1945
# Joy	0
# Sadness	4	epidemic, late, exhaustion, broke
# Anger	1	epidemic
# Fear	2	epidemic, broke
# Trust	1	frank
# Disgust	1	epidemic
# Surprise	1	epidemic
# Anticipation	2	epidemic, exhaustion
# Excitement	0
#
# Date Range: troops april 12 1945 to amsterdam june 3 1945
# Joy	0
# Sadness	0
# Anger	0
# Fear	0
# Trust	1	frank
# Disgust	0
# Surprise	0
# Anticipation	0
# Excitement	0
#
# Date Range: amsterdam june 3 1945 to death august 19 1980
# Joy	0
# Sadness	1	lost
# Anger	0
# Fear	0
# Trust	1	brother
# Disgust	0
# Surprise	0
# Anticipation	0
# Excitement	0

# %%
import csv
import docx
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Load the NRC Emotion Lexicon
nrc_lexicon_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\NRC-emotion-lexicon-wordlevel-alphabetized-v0.92.txt'
nrc_lexicon = {}

with open(nrc_lexicon_path, "r") as file:
    for line in file:
        word, emotion, value = line.strip().split("\t")
        if word in nrc_lexicon:
            nrc_lexicon[word][emotion] = int(value)
        else:
            nrc_lexicon[word] = {emotion: int(value)}

# Function to preprocess text and extract emotions
def extract_emotions_from_text(text):
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text.lower())
    preprocessed_tokens = [token for token in tokens if token.isalpha() and token not in stop_words]

    emotions = {'joy': set(), 'sadness': set(), 'anger': set(), 'fear': set(),
                'trust': set(), 'disgust': set(), 'surprise': set(), 'anticipation': set(), 'excitement': set()}

    for word in preprocessed_tokens:
        if word in nrc_lexicon:
            emotions_found = nrc_lexicon[word]
            for emotion, sentiment in emotions_found.items():
                if sentiment == 1 and emotion in emotions:
                    emotions[emotion].add(word)

    return emotions

# Function to find date pairs and extract emotions and words between them
def extract_emotions_between_date_pairs(diary_text):
    date_entries = re.findall(r"([A-Za-z]+day [A-Za-z]+ \d{1,2} \d{4})", diary_text)
    emotions_data_between_dates = []

    for i in range(len(date_entries) - 1):
        date1 = date_entries[i]
        date2 = date_entries[i + 1]

        # Find the text between two dates
        text_between_dates = re.search(f"{date1}(.+?){date2}", diary_text, re.DOTALL)

        if text_between_dates:
            text_between_dates = text_between_dates.group(1).strip()

            # Extract emotions from the text between dates
            emotions_data = extract_emotions_from_text(text_between_dates)

            # Append date range to the emotions data
            emotions_data['Date Range'] = f"{date1} to {date2}"
            emotions_data_between_dates.append(emotions_data)

    return emotions_data_between_dates

# Specify the document path
docx_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'

# Read the diary text from the document
doc = docx.Document(docx_path)
diary_text = "\n".join([paragraph.text for paragraph in doc.paragraphs])

# Extract emotions between date pairs
emotions_between_dates = extract_emotions_between_date_pairs(diary_text)

# Specify the CSV file path
csv_file_path = 'emotions_between_dates.csv'

# Write emotions data to CSV
with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Write header
    header = ['Date Range', 'Joy Count', 'Joy Words', 'Sadness Count', 'Sadness Words',
              'Anger Count', 'Anger Words', 'Fear Count', 'Fear Words',
              'Trust Count', 'Trust Words', 'Disgust Count', 'Disgust Words',
              'Surprise Count', 'Surprise Words', 'Anticipation Count', 'Anticipation Words',
              'Excitement Count', 'Excitement Words']
    writer.writerow(header)

    # Write data rows
    for emotions_data in emotions_between_dates:
        row = [emotions_data['Date Range']]
        for emotion in emotions.keys():
            count = len(emotions_data[emotion])
            distinct_words = ", ".join(emotions_data[emotion])
            row.extend([count, distinct_words])
        writer.writerow(row)

print(f"Emotions data between date pairs saved to {csv_file_path}")
# Out:
# Emotions data between date pairs saved to emotions_between_dates.csv

# %%
import csv
import docx
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Load the NRC Emotion Lexicon
nrc_lexicon_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\NRC-emotion-lexicon-wordlevel-alphabetized-v0.92.txt'
nrc_lexicon = {}

with open(nrc_lexicon_path, "r") as file:
    for line in file:
        word, emotion, value = line.strip().split("\t")
        if word in nrc_lexicon:
            nrc_lexicon[word][emotion] = int(value)
        else:
            nrc_lexicon[word] = {emotion: int(value)}

# Function to preprocess text and extract emotions
def extract_emotions_from_text(text):
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text.lower())
    preprocessed_tokens = [token for token in tokens if token.isalpha() and token not in stop_words]

    emotions = {'joy': set(), 'sadness': set(), 'anger': set(), 'fear': set(),
                'trust': set(), 'disgust': set(), 'surprise': set(), 'anticipation': set(), 'excitement': set()}

    for word in preprocessed_tokens:
        if word in nrc_lexicon:
            emotions_found = nrc_lexicon[word]
            for emotion, sentiment in emotions_found.items():
                if sentiment == 1 and emotion in emotions:
                    emotions[emotion].add(word)

    return emotions

# Function to calculate sentiment score
def calculate_sentiment_score(emotions_data):
    positive_emotions = ['joy', 'trust', 'anticipation', 'excitement']
    negative_emotions = ['sadness', 'anger', 'fear', 'disgust']

    positive_score = sum(len(emotions_data[emotion]) for emotion in positive_emotions)
    negative_score = sum(len(emotions_data[emotion]) for emotion in negative_emotions)

    sentiment_score = positive_score - negative_score
    return sentiment_score

# Function to find date pairs and extract emotions and words between them
def extract_emotions_between_date_pairs(diary_text):
    date_entries = re.findall(r"([A-Za-z]+day [A-Za-z]+ \d{1,2} \d{4})", diary_text)
    emotions_data_between_dates = []

    for i in range(len(date_entries) - 1):
        date1 = date_entries[i]
        date2 = date_entries[i + 1]

        # Find the text between two dates
        text_between_dates = re.search(f"{date1}(.+?){date2}", diary_text, re.DOTALL)

        if text_between_dates:
            text_between_dates = text_between_dates.group(1).strip()

            # Extract emotions from the text between dates
            emotions_data = extract_emotions_from_text(text_between_dates)

            # Calculate sentiment score
            sentiment_score = calculate_sentiment_score(emotions_data)
            emotions_data['Sentiment Score'] = sentiment_score

            # Append date range to the emotions data
            emotions_data['Date Range'] = f"{date1} to {date2}"
            emotions_data_between_dates.append(emotions_data)

    return emotions_data_between_dates

# Specify the document path
docx_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'

# Read the diary text from the document
doc = docx.Document(docx_path)
diary_text = "\n".join([paragraph.text for paragraph in doc.paragraphs])

# Extract emotions between date pairs
emotions_between_dates = extract_emotions_between_date_pairs(diary_text)

# Specify the CSV file path
csv_file_path = 'emotions_between_dates_with_sentiment.csv'

# Write emotions data to CSV
with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    # Write header
    header = ['Date Range', 'Joy Count', 'Joy Words', 'Sadness Count', 'Sadness Words',
              'Anger Count', 'Anger Words', 'Fear Count', 'Fear Words',
              'Trust Count', 'Trust Words', 'Disgust Count', 'Disgust Words',
              'Surprise Count', 'Surprise Words', 'Anticipation Count', 'Anticipation Words',
              'Excitement Count', 'Excitement Words', 'Sentiment Score']
    writer.writerow(header)

    # Write data rows
    for emotions_data in emotions_between_dates:
        row = [emotions_data['Date Range']]
        for emotion in emotions.keys():
            count = len(emotions_data[emotion])
            distinct_words = ", ".join(emotions_data[emotion])
            row.extend([count, distinct_words])
        row.append(emotions_data['Sentiment Score'])
        writer.writerow(row)

print(f"Emotions data between date pairs with sentiment score saved to {csv_file_path}")
# Out:
# Emotions data between date pairs with sentiment score saved to emotions_between_dates_with_sentiment.csv

# %%
import csv
import docx
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Load the NRC Emotion Lexicon
nrc_lexicon_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\NRC-emotion-lexicon-wordlevel-alphabetized-v0.92.txt'
nrc_lexicon = {}

with open(nrc_lexicon_path, "r") as file:
    for line in file:
        word, emotion, value = line.strip().split("\t")
        if word in nrc_lexicon:
            nrc_lexicon[word][emotion] = int(value)
        else:
            nrc_lexicon[word] = {emotion: int(value)}

# Function to preprocess text and extract emotions
def extract_emotions_from_text(text):
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text.lower())
    preprocessed_tokens = [token for token in tokens if token.isalpha() and token not in stop_words]

    emotions = {'joy': set(), 'sadness': set(), 'anger': set(), 'fear': set(),
                'trust': set(), 'disgust': set(), 'surprise': set(), 'anticipation': set(), 'excitement': set()}

    for word in preprocessed_tokens:
        if word in nrc_lexicon:
            emotions_found = nrc_lexicon[word]
            for emotion, sentiment in emotions_found.items():
                if sentiment == 1 and emotion in emotions:
                    emotions[emotion].add(word)

    return emotions

# Function to calculate sentiment score
def calculate_sentiment_score(emotions_data):
    positive_emotions = ['joy', 'trust', 'anticipation', 'excitement']
    negative_emotions = ['sadness', 'anger', 'fear', 'disgust']

    positive_score = sum(len(emotions_data[emotion]) for emotion in positive_emotions)
    negative_score = sum(len(emotions_data[emotion]) for emotion in negative_emotions)

    sentiment_score = positive_score - negative_score
    return sentiment_score

# Function to label sentiment based on sentiment score
def label_sentiment(sentiment_score):
    if sentiment_score > 1:
        return "Very Positive"
    elif sentiment_score == 1:
        return "Positive"
    elif sentiment_score == 0:
        return "Neutral"
    elif sentiment_score == -1:
        return "Negative"
    else:
        return "Very Negative"

# Function to find date pairs and extract emotions and words between them
def extract_emotions_between_date_pairs(diary_text):
    date_entries = re.findall(r"([A-Za-z]+day [A-Za-z]+ \d{1,2} \d{4})", diary_text)
    emotions_data_between_dates = []

    for i in range(len(date_entries) - 1):
        date1 = date_entries[i]
        date2 = date_entries[i + 1]

        # Find the text between two dates
        text_between_dates = re.search(f"{date1}(.+?){date2}", diary_text, re.DOTALL)

        if text_between_dates:
            text_between_dates = text_between_dates.group(1).strip()

            # Extract emotions from the text between dates
            emotions_data = extract_emotions_from_text(text_between_dates)

            # Calculate sentiment score
            sentiment_score = calculate_sentiment_score(emotions_data)
            
            # Label sentiment
            sentiment_label = label_sentiment(sentiment_score)
            emotions_data['Sentiment Label'] = sentiment_label

            # Append date range to the emotions data
            emotions_data['Date Range'] = f"{date1} to {date2}"
            emotions_data_between_dates.append(emotions_data)

    return emotions_data_between_dates

# Specify the document path
docx_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'

# Read the diary text from the document
doc = docx.Document(docx_path)
diary_text = "\n".join([paragraph.text for paragraph in doc.paragraphs])

# Extract emotions between date pairs
emotions_between_dates = extract_emotions_between_date_pairs(diary_text)

# Specify the CSV file path
csv_file_path = 'emotions_between_dates_with_sentiment_labels.csv'

# Write emotions data to CSV
with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    # Write header
    header = ['Date Range', 'Joy Count', 'Joy Words', 'Sadness Count', 'Sadness Words',
              'Anger Count', 'Anger Words', 'Fear Count', 'Fear Words',
              'Trust Count', 'Trust Words', 'Disgust Count', 'Disgust Words',
              'Surprise Count', 'Surprise Words', 'Anticipation Count', 'Anticipation Words',
              'Excitement Count', 'Excitement Words', 'Sentiment Label']
    writer.writerow(header)

    # Write data rows
    for emotions_data in emotions_between_dates:
        row = [emotions_data['Date Range']]
        for emotion in emotions.keys():
            count = len(emotions_data[emotion])
            distinct_words = ", ".join(emotions_data[emotion])
            row.extend([count, distinct_words])
        row.append(emotions_data['Sentiment Label'])
        writer.writerow(row)

print(f"Emotions data between date pairs with sentiment labels saved to {csv_file_path}")
# Out:
# Emotions data between date pairs with sentiment labels saved to emotions_between_dates_with_sentiment_labels.csv

# %%
import csv
import docx
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Load the NRC Emotion Lexicon
nrc_lexicon_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\NRC-emotion-lexicon-wordlevel-alphabetized-v0.92.txt'
nrc_lexicon = {}

with open(nrc_lexicon_path, "r") as file:
    for line in file:
        word, emotion, value = line.strip().split("\t")
        if word in nrc_lexicon:
            nrc_lexicon[word][emotion] = int(value)
        else:
            nrc_lexicon[word] = {emotion: int(value)}

# Function to preprocess text and extract emotions
def extract_emotions_from_text(text):
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text.lower())
    preprocessed_tokens = [token for token in tokens if token.isalpha() and token not in stop_words]

    emotions = {'joy': set(), 'sadness': set(), 'anger': set(), 'fear': set(),
                'trust': set(), 'disgust': set(), 'surprise': set(), 'anticipation': set()}

    for word in preprocessed_tokens:
        if word in nrc_lexicon:
            emotions_found = nrc_lexicon[word]
            for emotion, sentiment in emotions_found.items():
                if sentiment == 1 and emotion in emotions:
                    emotions[emotion].add(word)

    return emotions

# Function to calculate sentiment score
def calculate_sentiment_score(emotions_data):
    positive_emotions = ['joy', 'trust', 'anticipation']
    negative_emotions = ['sadness', 'anger', 'fear', 'disgust']

    positive_score = sum(len(emotions_data[emotion]) for emotion in positive_emotions)
    negative_score = sum(len(emotions_data[emotion]) for emotion in negative_emotions)

    sentiment_score = positive_score - negative_score
    return sentiment_score

# Function to label sentiment based on sentiment score
def label_sentiment(sentiment_score):
    if sentiment_score > 1:
        return "Very Positive"
    elif sentiment_score == 1:
        return "Positive"
    elif sentiment_score == 0:
        return "Neutral"
    elif sentiment_score == -1:
        return "Negative"
    else:
        return "Very Negative"

# Function to find date pairs and extract emotions and words between them
def extract_emotions_between_date_pairs(diary_text):
    date_entries = re.findall(r"([A-Za-z]+day [A-Za-z]+ \d{1,2} \d{4})", diary_text)
    emotions_data_between_dates = []

    for i in range(len(date_entries) - 1):
        date1 = date_entries[i]
        date2 = date_entries[i + 1]

        # Find the text between two dates
        text_between_dates = re.search(f"{date1}(.+?){date2}", diary_text, re.DOTALL)

        if text_between_dates:
            text_between_dates = text_between_dates.group(1).strip()

            # Extract emotions from the text between dates
            emotions_data = extract_emotions_from_text(text_between_dates)

            # Calculate sentiment score
            sentiment_score = calculate_sentiment_score(emotions_data)
            
            # Label sentiment
            sentiment_label = label_sentiment(sentiment_score)
            emotions_data['Sentiment Score'] = sentiment_score
            emotions_data['Sentiment Label'] = sentiment_label

            # Append date range to the emotions data
            emotions_data['Date Range'] = f"{date1} to {date2}"
            emotions_data_between_dates.append(emotions_data)

    return emotions_data_between_dates

# Specify the document path
docx_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Filtered_Anne-Frank-The-Diary-Of-A-Young-Girl.docx'

# Read the diary text from the document
doc = docx.Document(docx_path)
diary_text = "\n".join([paragraph.text for paragraph in doc.paragraphs])

# Extract emotions between date pairs
emotions_between_dates = extract_emotions_between_date_pairs(diary_text)

# Specify the CSV file path
csv_file_path = 'emotions_between_dates_with_sentiment.csv'

# Write emotions data to CSV
with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    # Write header
    header = ['Date Range', 'Joy Count', 'Joy Words', 'Sadness Count', 'Sadness Words',
              'Anger Count', 'Anger Words', 'Fear Count', 'Fear Words',
              'Trust Count', 'Trust Words', 'Disgust Count', 'Disgust Words',
              'Surprise Count', 'Surprise Words', 'Anticipation Count', 'Anticipation Words',
              'Sentiment Score', 'Sentiment Label']
    writer.writerow(header)

    # Write data rows
    for emotions_data in emotions_between_dates:
        row = [emotions_data['Date Range']]
        for emotion_key in emotions_data.keys():
            if emotion_key not in ['Date Range', 'Sentiment Score', 'Sentiment Label']:
                count = len(emotions_data[emotion_key])
                distinct_words = ", ".join(emotions_data[emotion_key])
                row.extend([count, distinct_words])
        row.extend([emotions_data['Sentiment Score'], emotions_data['Sentiment Label']])
        writer.writerow(row)

print(f"Emotions data between date pairs with sentiment saved to {csv_file_path}")
# Out:
# Emotions data between date pairs with sentiment saved to emotions_between_dates_with_sentiment.csv
