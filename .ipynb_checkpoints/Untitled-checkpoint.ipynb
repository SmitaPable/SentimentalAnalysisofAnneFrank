# %%
pip install PyPDF2 nltk spellchecker
# Out:
# ...
#
# ...
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)

# %%
import re
from PyPDF2 import PdfReader
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from spellchecker import SpellChecker

# Ensure you have the necessary NLTK datasets
import nltk
nltk.download('punkt')
nltk.download('stopwords')

# Step 1: Read PDF content
def extract_text_from_pdf(pdf_path):
    reader = PdfReader(pdf_path)
    text = ""
    for page in reader.pages:
        text += page.extract_text()
    return text

# Step 2: Clean text
def clean_text(text):
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)  # remove non-alphanumeric chars
    text = re.sub(r'\s+', ' ', text).strip()  # remove extra whitespaces
    return text.lower()

# Step 3: Tokenize text
def tokenize_text(text):
    return word_tokenize(text)

# Step 4: Remove stopwords
def remove_stopwords(tokens):
    stop_words = set(stopwords.words('english'))
    return [token for token in tokens if token not in stop_words]

# Step 5: Correct spelling
def correct_spelling(tokens):
    spell = SpellChecker()
    return [spell.correction(token) for token in tokens]

# Step 6: Perform stemming
def stem_tokens(tokens):
    stemmer = PorterStemmer()
    return [stemmer.stem(token) for token in tokens]

# Combine all steps to clean the PDF
def clean_pdf(pdf_path):
    # Read and clean text
    text = extract_text_from_pdf(pdf_path)
    text = clean_text(text)
    
    # Tokenize text
    tokens = tokenize_text(text)
    
    # Remove stopwords
    tokens = remove_stopwords(tokens)
    
    # Correct spelling
    tokens = correct_spelling(tokens)
    
    # Perform stemming
    tokens = stem_tokens(tokens)
    
    return tokens

# Example usage:
pdf_path = r"C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl.pdf"

cleaned_tokens = clean_pdf(pdf_path)
print(cleaned_tokens)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 69
#      66 # Example usage:
#      67 pdf_path = r"C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl.pdf"
# ---> 69 cleaned_tokens = clean_pdf(pdf_path)
#      70 print(cleaned_tokens)
#
# Cell In[11], line 62, in clean_pdf(pdf_path)
#      59 tokens = correct_spelling(tokens)
#      61 # Perform stemming
# ---> 62 tokens = stem_tokens(tokens)
#      64 return tokens
#
# Cell In[11], line 44, in stem_tokens(tokens)
#      42 def stem_tokens(tokens):
# ...

# %%
import re
from PyPDF2 import PdfReader
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from spellchecker import SpellChecker
import nltk

# Download NLTK datasets if not already downloaded
nltk.download('punkt')
nltk.download('stopwords')

# Step 1: Read PDF content
def extract_text_from_pdf(pdf_path):
    reader = PdfReader(pdf_path)
    text = ""
    for page in reader.pages:
        text += page.extract_text()
    return text

# Step 2: Clean text
def clean_text(text):
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)  # remove non-alphanumeric chars
    text = re.sub(r'\s+', ' ', text).strip()  # remove extra whitespaces
    return text.lower()

# Step 3: Tokenize text
def tokenize_text(text):
    return word_tokenize(text)

# Step 4: Remove stopwords
def remove_stopwords(tokens):
    stop_words = set(stopwords.words('english'))
    return [token for token in tokens if token not in stop_words]

# Step 5: Correct spelling
def correct_spelling(tokens):
    spell = SpellChecker()
    return [spell.correction(token) for token in tokens]

# Step 6: Perform stemming
def stem_tokens(tokens):
    stemmer = PorterStemmer()
    return [stemmer.stem(token) for token in tokens]

# Combine all steps to clean the PDF
def clean_pdf(pdf_path):
    # Read and clean text
    text = extract_text_from_pdf(pdf_path)
    text = clean_text(text)
    
    # Tokenize text
    tokens = tokenize_text(text)
    
    # Remove stopwords
    tokens = remove_stopwords(tokens)
    
    # Correct spelling
    tokens = correct_spelling(tokens)
    
    # Perform stemming
    tokens = stem_tokens(tokens)
    
    return tokens

# Example usage:
pdf_path = r"C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl.pdf"

cleaned_tokens = clean_pdf(pdf_path)
print(cleaned_tokens)

# %%
pip install PyPDF2 nltk spellchecker
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)

# %%
import re
from PyPDF2 import PdfReader
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from spellchecker import SpellChecker
import nltk

# Download NLTK datasets if not already downloaded
nltk.download('punkt')
nltk.download('stopwords')

# Step 1: Read PDF content
def extract_text_from_pdf(pdf_path):
    reader = PdfReader(pdf_path)
    text = ""
    for page in reader.pages:
        text += page.extract_text()
    return text

# Step 2: Clean text
def clean_text(text):
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)  # remove non-alphanumeric chars
    text = re.sub(r'\s+', ' ', text).strip()  # remove extra whitespaces
    return text.lower()

# Step 3: Tokenize text
def tokenize_text(text):
    return word_tokenize(text)

# Step 4: Remove stopwords
def remove_stopwords(tokens):
    stop_words = set(stopwords.words('english'))
    return [token for token in tokens if token not in stop_words]

# Step 5: Correct spelling
def correct_spelling(tokens):
    spell = SpellChecker()
    return [spell.correction(token) for token in tokens]

# Step 6: Perform stemming
def stem_tokens(tokens):
    stemmer = PorterStemmer()
    return [stemmer.stem(token) for token in tokens]

# Combine all steps to clean the PDF
def clean_pdf(pdf_path):
    # Read and clean text
    text = extract_text_from_pdf(pdf_path)
    print("Extracted Text:", text)  # Debug print
    text = clean_text(text)
    print("Cleaned Text:", text)  # Debug print
    
    # Tokenize text
    tokens = tokenize_text(text)
    print("Tokenized Text:", tokens)  # Debug print
    
    # Remove stopwords
    tokens = remove_stopwords(tokens)
    print("Without Stopwords:", tokens)  # Debug print
    
    # Correct spelling
    tokens = correct_spelling(tokens)
    print("Corrected Spelling:", tokens)  # Debug print
    
    # Perform stemming
    tokens = stem_tokens(tokens)
    print("Stemmed Tokens:", tokens)  # Debug print
    
    return tokens

# Example usage:
pdf_path = r"C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl.pdf"

cleaned_tokens = clean_pdf(pdf_path)
print(cleaned_tokens)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Extracted Text: THE DIARY OF A YOUNG GIRL : THE DEFINITIVE EDITION
# Anne Frank
# Edited by Otto H. Frank and Mirjam Pressler
# Translated by Susan Massotty
# -- : --
# BOOK FLAP
# Anne Frank's The Diary of a Young Girl is among the most enduri ng documents of the
# twentieth century. Since its publication in 1947, it has bee n read by tens of millions
# of people all over the world. It remains a beloved and deeply a dmired testament to the
# indestructable nature of the human spirit.
# Restore in this Definitive Edition are diary entries that ha d been omitted from the
# original edition. These passages, which constitute 30 perc ent more material, reinforce
# ...

# %%
import re
from PyPDF2 import PdfReader
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Download NLTK datasets if not already downloaded
nltk.download('punkt')
nltk.download('stopwords')

# Step 1: Text Extraction
def extract_text_from_pdf(pdf_path):
    reader = PdfReader(pdf_path)
    text = ""
    for page in reader.pages:
        text += page.extract_text()
    return text

# Step 2: Data Cleaning
def clean_text(text):
    # Remove non-alphanumeric characters and extra whitespaces
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    
    # Convert text to lowercase
    text = text.lower()
    
    # Tokenize text
    tokens = word_tokenize(text)
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    
    return tokens

# Combine text extraction and data cleaning
def preprocess_diary(pdf_path):
    # Step 1: Text Extraction
    extracted_text = extract_text_from_pdf(pdf_path)
    print("Extracted Text:", extracted_text[:500])  # Print first 500 characters as a sample
    
    # Step 2: Data Cleaning
    cleaned_tokens = clean_text(extracted_text)
    print("Cleaned Tokens:", cleaned_tokens[:20])  # Print first 20 tokens as a sample
    
    return cleaned_tokens

# Example usage:
pdf_path = r"C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl.pdf"
preprocessed_data = preprocess_diary(pdf_path)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Extracted Text: THE DIARY OF A YOUNG GIRL : THE DEFINITIVE EDITION
# Anne Frank
# Edited by Otto H. Frank and Mirjam Pressler
# Translated by Susan Massotty
# -- : --
# BOOK FLAP
# Anne Frank's The Diary of a Young Girl is among the most enduri ng documents of the
# twentieth century. Since its publication in 1947, it has bee n read by tens of millions
# of people all over the world. It remains a beloved and deeply a dmired testament to the
# indestructable nature of the human spirit.
# Restore in this Definitive Edition
# ...

# %%
import re
from PyPDF2 import PdfReader
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Download NLTK datasets if not already downloaded
nltk.download('punkt')
nltk.download('stopwords')

# Step 1: Text Extraction
def extract_text_from_pdf(pdf_path):
    reader = PdfReader(pdf_path)
    text = ""
    for page in reader.pages:
        text += page.extract_text()
    return text

# Step 2: Data Cleaning
def clean_text(text):
    # Remove non-alphanumeric characters and extra whitespaces
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    
    # Convert text to lowercase
    text = text.lower()
    
    # Tokenize text
    tokens = word_tokenize(text)
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    
    return tokens

# Step 3: Save to File
def save_to_file(tokens, output_file):
    with open(output_file, 'w', encoding='utf-8') as file:
        file.write(' '.join(tokens))

# Combine text extraction, data cleaning, and save to file
def preprocess_and_save(pdf_path, output_file):
    # Step 1: Text Extraction
    extracted_text = extract_text_from_pdf(pdf_path)
    print("Extracted Text:", extracted_text[:500])  # Print first 500 characters as a sample
    
    # Step 2: Data Cleaning
    cleaned_tokens = clean_text(extracted_text)
    print("Cleaned Tokens:", cleaned_tokens[:20])  # Print first 20 tokens as a sample
    
    # Step 3: Save to File
    save_to_file(cleaned_tokens, output_file)
    print(f"Cleaned Tokens saved to {output_file}")

# Example usage:
pdf_path = r"C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl.pdf"
output_file = r"C:\Users\DELL\Desktop\Project\cleaned_tokens.txt"

preprocess_and_save(pdf_path, output_file)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Extracted Text: THE DIARY OF A YOUNG GIRL : THE DEFINITIVE EDITION
# Anne Frank
# Edited by Otto H. Frank and Mirjam Pressler
# Translated by Susan Massotty
# -- : --
# BOOK FLAP
# Anne Frank's The Diary of a Young Girl is among the most enduri ng documents of the
# twentieth century. Since its publication in 1947, it has bee n read by tens of millions
# of people all over the world. It remains a beloved and deeply a dmired testament to the
# indestructable nature of the human spirit.
# Restore in this Definitive Edition
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report

# Read the contents of the text file
file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl-cleaned_tokens.txt'  # Replace with the actual path to your text file
with open(file_path, 'r', encoding='utf-8') as file:
    lines = file.readlines()

# Assuming your text file has one entry per line, and each line is a piece of text with a corresponding sentiment label
data = [line.strip().split('\t') for line in lines]

# Convert to DataFrame
import pandas as pd
df = pd.DataFrame(data, columns=['text', 'sentiment'])

# Split the data
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['sentiment'], test_size=0.2, random_state=42)

# Feature extraction using CountVectorizer
vectorizer = CountVectorizer()
X_train_vectors = vectorizer.fit_transform(X_train)
X_test_vectors = vectorizer.transform(X_test)

# Train a Naive Bayes classifier
classifier = MultinomialNB()
classifier.fit(X_train_vectors, y_train)

# Predict on the test set
predictions = classifier.predict(X_test_vectors)

# Evaluate the model
print("Classification Report:")
print(classification_report(y_test, predictions))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File D:\Anaconda\lib\site-packages\pandas\core\internals\construction.py:969, in _finalize_columns_and_data(content, columns, dtype)
#     968 try:
# --> 969     columns = _validate_or_indexify_columns(contents, columns)
#     970 except AssertionError as err:
#     971     # GH#26429 do not raise user-facing AssertionError
#
# File D:\Anaconda\lib\site-packages\pandas\core\internals\construction.py:1017, in _validate_or_indexify_columns(content, columns)
#    1015 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#    1016     # caller's responsibility to check for this...
# -> 1017     raise AssertionError(
#    1018         f"{len(columns)} columns passed, passed data had "
#    1019         f"{len(content)} columns"
#    1020     )
#    1021 elif is_mi_list:
#    1022
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report

# Read the contents of the text file
file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl-cleaned_tokens.txt'  # Replace with the actual path to your text file
with open(file_path, 'r', encoding='utf-8') as file:
    lines = file.readlines()

# Print the first few lines of the loaded data to understand its structure
print("First few lines of the loaded data:")
for line in lines[:5]:
    print(line)

# Assuming your text file has one entry per line, and each line is a piece of text with a corresponding sentiment label
data = [line.strip().split('\t') for line in lines]

# Print the first few rows of the loaded data after splitting
print("\nFirst few rows after splitting:")
for row in data[:5]:
    print(row)

# Convert to DataFrame
import pandas as pd
df = pd.DataFrame(data, columns=['text', 'sentiment'])

# Print some information about the DataFrame
print("\nDataFrame information:")
print(df.info())

# Split the data
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['sentiment'], test_size=0.2, random_state=42)

# Feature extraction using CountVectorizer
vectorizer = CountVectorizer()
X_train_vectors = vectorizer.fit_transform(X_train)
X_test_vectors = vectorizer.transform(X_test)

# Train a Naive Bayes classifier
classifier = MultinomialNB()
classifier.fit(X_train_vectors, y_train)

# Predict on the test set
predictions = classifier.predict(X_test_vectors)

# Evaluate the model
print("\nClassification Report:")
print(classification_report(y_test, predictions))
# Out:
# First few lines of the loaded data:
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report

# Read the contents of the text file
file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl-cleaned_tokens.txt'  # Replace with the actual path to your text file
with open(file_path, 'r', encoding='utf-8') as file:
    lines = file.readlines()

# Assuming each line is a single string with text and sentiment separated by a tab
data = [line.strip().split('\t') for line in lines]

# Convert to DataFrame
import pandas as pd
df = pd.DataFrame(data, columns=['text'])

# Add an empty 'sentiment' column for now
df['sentiment'] = ''

# Create separate Series for 'text' and 'sentiment'
text_sentiment_series = df['text'].str.split('\t', 1, expand=True)

# Assign the Series to DataFrame columns
df['text'] = text_sentiment_series[0]
df['sentiment'] = text_sentiment_series[1]

# Split the data
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['sentiment'], test_size=0.2, random_state=42)

# Feature extraction using CountVectorizer
vectorizer = CountVectorizer()
X_train_vectors = vectorizer.fit_transform(X_train)
X_test_vectors = vectorizer.transform(X_test)

# Train a Naive Bayes classifier
classifier = MultinomialNB()
classifier.fit(X_train_vectors, y_train)

# Predict on the test set
predictions = classifier.predict(X_test_vectors)

# Evaluate the model
print("Classification Report:")
print(classification_report(y_test, predictions))
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13504\1689759108.py:22: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   text_sentiment_series = df['text'].str.split('\t', 1, expand=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File D:\Anaconda\lib\site-packages\pandas\core\indexes\range.py:391, in RangeIndex.get_loc(self, key, method, tolerance)
#     390 try:
# --> 391     return self._range.index(new_key)
#     392 except ValueError as err:
#
# ValueError: 1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 26
#      24 # Assign the Series to DataFrame columns
#      25 df['text'] = text_sentiment_series[0]
# ...

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

# Read data from a text file
file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl-cleaned_tokens.txt'
with open(file_path, 'r', encoding='utf-8') as file:
    lines = file.readlines()

# Assuming each line in the text file contains a data point (text and sentiment label separated by a delimiter)
# Modify the following line based on your data format
data = [line.strip().split('\t') for line in lines]

# Create a DataFrame
# If your data has only one column (text), create a DataFrame with a single column 'text'
df = pd.DataFrame(data, columns=['text'])

# Feature extraction using CountVectorizer
vectorizer = CountVectorizer()
X_vectors = vectorizer.fit_transform(df['text'])

# Sentiment labels
y_labels = ['Hopeful', 'Curious', 'Affectionate', 'Fearful', 'Frustrated', 'Lonely', 'Reflective']

# Ensure the number of samples in X_vectors and the DataFrame match
if X_vectors.shape[0] != len(df):
    raise ValueError("Inconsistent number of samples between X_vectors and the DataFrame.")

# Train a Naive Bayes classifier on the entire dataset
classifier = MultinomialNB()
classifier.fit(X_vectors, y_labels)

# Predict on the entire dataset
predictions = classifier.predict(X_vectors)

# Evaluate the model
accuracy = accuracy_score(y_labels, predictions)
print(f"Accuracy: {accuracy}")

print("Classification Report:")
print(classification_report(y_labels, predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 32
#      30 # Train a Naive Bayes classifier on the entire dataset
#      31 classifier = MultinomialNB()
# ---> 32 classifier.fit(X_vectors, y_labels)
#      34 # Predict on the entire dataset
#      35 predictions = classifier.predict(X_vectors)
#
# File D:\Anaconda\lib\site-packages\sklearn\naive_bayes.py:749, in _BaseDiscreteNB.fit(self, X, y, sample_weight)
#     729 """Fit Naive Bayes classifier according to X, y.
#     730
#     731 Parameters
#    (...)
#     746     Returns the instance itself.
#     747 """
#     748 self._validate_params()
# --> 749 X, y = self._check_X_y(X, y)
#     750 _, n_features = X.shape
#     752 labelbin = LabelBinarizer()
#
# File D:\Anaconda\lib\site-packages\sklearn\naive_bayes.py:583, in _BaseDiscreteNB._check_X_y(self, X, y, reset)
# ...

# %%
# Ensure the number of samples in X_vectors and the DataFrame match
print("Number of samples in X_vectors:", X_vectors.shape[0])
print("Number of labels in y_labels:", len(y_labels))

if X_vectors.shape[0] != len(y_labels):
    raise ValueError("Inconsistent number of samples between X_vectors and y_labels.")

# Train a Naive Bayes classifier on the entire dataset
classifier = MultinomialNB()
classifier.fit(X_vectors, y_labels)

# Predict on the entire dataset
predictions = classifier.predict(X_vectors)
# Out:
# Number of samples in X_vectors: 1
# Number of labels in y_labels: 7
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 6
#       3 print("Number of labels in y_labels:", len(y_labels))
#       5 if X_vectors.shape[0] != len(y_labels):
# ----> 6     raise ValueError("Inconsistent number of samples between X_vectors and y_labels.")
#       8 # Train a Naive Bayes classifier on the entire dataset
#       9 classifier = MultinomialNB()
#
# ValueError: Inconsistent number of samples between X_vectors and y_labels.

# %%
# Assuming each line in the text file contains a data point (text and sentiment label separated by a delimiter)
# Modify the following line based on your data format
data = [line.strip().split('\t') for line in lines]

# Create a DataFrame
# If your data has only one column (text), create a DataFrame with a single column 'text'
df = pd.DataFrame(data, columns=['text', 'sentiment'])

# Feature extraction using CountVectorizer
vectorizer = CountVectorizer()
X_vectors = vectorizer.fit_transform(df['text'])

# Sentiment labels
y_labels = df['sentiment'].tolist()

# Ensure the number of samples in X_vectors and the DataFrame match
if X_vectors.shape[0] != len(y_labels):
    raise ValueError("Inconsistent number of samples between X_vectors and y_labels.")

# Train a Naive Bayes classifier on the entire dataset
classifier = MultinomialNB()
classifier.fit(X_vectors, y_labels)

# Predict on the entire dataset
predictions = classifier.predict(X_vectors)

# Evaluate the model
accuracy = accuracy_score(y_labels, predictions)
print(f"Accuracy: {accuracy}")

print("Classification Report:")
print(classification_report(y_labels, predictions))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File D:\Anaconda\lib\site-packages\pandas\core\internals\construction.py:969, in _finalize_columns_and_data(content, columns, dtype)
#     968 try:
# --> 969     columns = _validate_or_indexify_columns(contents, columns)
#     970 except AssertionError as err:
#     971     # GH#26429 do not raise user-facing AssertionError
#
# File D:\Anaconda\lib\site-packages\pandas\core\internals\construction.py:1017, in _validate_or_indexify_columns(content, columns)
#    1015 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#    1016     # caller's responsibility to check for this...
# -> 1017     raise AssertionError(
#    1018         f"{len(columns)} columns passed, passed data had "
#    1019         f"{len(content)} columns"
#    1020     )
#    1021 elif is_mi_list:
#    1022
# ...

# %%
# Read data from a text file
file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl-cleaned_tokens.txt'
with open(file_path, 'r', encoding='utf-8') as file:
    lines = file.readlines()

# Create a DataFrame with a single column 'text'
df = pd.DataFrame(lines, columns=['text'])

# Feature extraction using CountVectorizer
vectorizer = CountVectorizer()
X_vectors = vectorizer.fit_transform(df['text'])

# Sentiment labels
y_labels = ['Hopeful', 'Curious', 'Affectionate', 'Fearful', 'Frustrated', 'Lonely', 'Reflective']

# Ensure the number of samples in X_vectors and the DataFrame match
if X_vectors.shape[0] != len(df):
    raise ValueError("Inconsistent number of samples between X_vectors and the DataFrame.")

# Train a Naive Bayes classifier on the entire dataset
classifier = MultinomialNB()
classifier.fit(X_vectors, y_labels)

# Predict on the entire dataset
predictions = classifier.predict(X_vectors)

# Evaluate the model
accuracy = accuracy_score(y_labels, predictions)
print(f"Accuracy: {accuracy}")

print("Classification Report:")
print(classification_report(y_labels, predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 22
#      20 # Train a Naive Bayes classifier on the entire dataset
#      21 classifier = MultinomialNB()
# ---> 22 classifier.fit(X_vectors, y_labels)
#      24 # Predict on the entire dataset
#      25 predictions = classifier.predict(X_vectors)
#
# File D:\Anaconda\lib\site-packages\sklearn\naive_bayes.py:749, in _BaseDiscreteNB.fit(self, X, y, sample_weight)
#     729 """Fit Naive Bayes classifier according to X, y.
#     730
#     731 Parameters
#    (...)
#     746     Returns the instance itself.
#     747 """
#     748 self._validate_params()
# --> 749 X, y = self._check_X_y(X, y)
#     750 _, n_features = X.shape
#     752 labelbin = LabelBinarizer()
#
# File D:\Anaconda\lib\site-packages\sklearn\naive_bayes.py:583, in _BaseDiscreteNB._check_X_y(self, X, y, reset)
# ...

# %%
# Import necessary libraries
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

# Read data from a text file
file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl-cleaned_tokens.txt'
with open(file_path, 'r', encoding='utf-8') as file:
    lines = file.readlines()

# Assuming each line in the text file contains a data point (text and sentiment label separated by a delimiter)
# Modify the following line based on your data format
data = [line.strip().split('\t') for line in lines]

# Create a DataFrame
# If your data has only one column (text), create a DataFrame with a single column 'text'
df = pd.DataFrame(data, columns=['text'])

# Feature extraction using CountVectorizer
vectorizer = CountVectorizer()
X_vectors = vectorizer.fit_transform(df['text'])

# Sentiment labels
y_labels = ['Hopeful', 'Curious', 'Affectionate', 'Fearful', 'Frustrated', 'Lonely', 'Reflective']

# Ensure the number of samples in X_vectors and the DataFrame match
if X_vectors.shape[0] != len(df):
    raise ValueError("Inconsistent number of samples between X_vectors and the DataFrame.")

# Train a Naive Bayes classifier on the entire dataset
classifier = MultinomialNB()
classifier.fit(X_vectors, y_labels)

# Predict on the entire dataset
predictions = classifier.predict(X_vectors)

# Evaluate the model
accuracy = accuracy_score(y_labels, predictions)
print(f"Accuracy: {accuracy}")

print("Classification Report:")
print(classification_report(y_labels, predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 33
#      31 # Train a Naive Bayes classifier on the entire dataset
#      32 classifier = MultinomialNB()
# ---> 33 classifier.fit(X_vectors, y_labels)
#      35 # Predict on the entire dataset
#      36 predictions = classifier.predict(X_vectors)
#
# File D:\Anaconda\lib\site-packages\sklearn\naive_bayes.py:749, in _BaseDiscreteNB.fit(self, X, y, sample_weight)
#     729 """Fit Naive Bayes classifier according to X, y.
#     730
#     731 Parameters
#    (...)
#     746     Returns the instance itself.
#     747 """
#     748 self._validate_params()
# --> 749 X, y = self._check_X_y(X, y)
#     750 _, n_features = X.shape
#     752 labelbin = LabelBinarizer()
#
# File D:\Anaconda\lib\site-packages\sklearn\naive_bayes.py:583, in _BaseDiscreteNB._check_X_y(self, X, y, reset)
# ...

# %%
# Define the path for your text data and the output file
input_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Gir.pdf'
output_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\labeled_data.txt'

# Define your sentiment labels
sentiment_labels = ['Hopeful', 'Curious', 'Affectionate', 'Fearful', 'Frustrated', 'Lonely', 'Reflective']

# Function to manually label the data
def label_data(input_path, output_path, labels):
    with open(input_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    with open(output_path, 'w', encoding='utf-8') as outfile:
        for line in lines:
            print("\nText to label:")
            print(line)
            print("\nChoose a label from the following:")
            for i, label in enumerate(labels):
                print(f"{i}: {label}")
            label_index = input("Enter the label number (or 'skip' to skip): ")
            if label_index.isdigit() and int(label_index) in range(len(labels)):
                labeled_line = line.strip() + "\t" + labels[int(label_index)] + "\n"
                outfile.write(labeled_line)
            elif label_index == 'skip':
                continue
            else:
                print("Invalid input, skipping to next.")

# Start the labeling process
label_data(input_file_path, output_file_path, sentiment_labels)

print("Data labeling complete.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 30
#      27                 print("Invalid input, skipping to next.")
#      29 # Start the labeling process
# ---> 30 label_data(input_file_path, output_file_path, sentiment_labels)
#      32 print("Data labeling complete.")
#
# Cell In[17], line 10, in label_data(input_path, output_path, labels)
#       9 def label_data(input_path, output_path, labels):
# ---> 10     with open(input_path, 'r', encoding='utf-8') as file:
#      11         lines = file.readlines()
#      13     with open(output_path, 'w', encoding='utf-8') as outfile:
#
# File D:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
# ...

# %%
import re
import PyPDF2
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Define the path for your PDF file
pdf_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl.pdf'
output_file_path = 'output_text_file.txt'

# Initialize stemmer
stemmer = PorterStemmer()

# Function to preprocess text
def preprocess_text(text):
    # Normalize text
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation

    # Tokenize text
    tokens = word_tokenize(text)

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]

    # Stemming
    stemmed_tokens = [stemmer.stem(word) for word in filtered_tokens]

    return ' '.join(stemmed_tokens)

# Read the PDF file
def extract_text_from_pdf(pdf_path):
    text_content = ''

    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfFileReader(file)
        for page in range(reader.numPages):
            text_content += reader.getPage(page).extractText()
    
    return text_content

# Extract text from PDF
pdf_text = extract_text_from_pdf(pdf_file_path)

# Preprocess text
preprocessed_text = preprocess_text(pdf_text)

# Write the preprocessed text to a new file
with open(output_file_path, 'w', encoding='utf-8') as output_file:
    output_file.write(preprocessed_text)

print("Preprocessing complete. Output saved to", output_file_path)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# DeprecationError                          Traceback (most recent call last)
# Cell In[2], line 51
#      48     return text_content
#      50 # Extract text from PDF
# ---> 51 pdf_text = extract_text_from_pdf(pdf_file_path)
#      53 # Preprocess text
#      54 preprocessed_text = preprocess_text(pdf_text)
#
# Cell In[2], line 44, in extract_text_from_pdf(pdf_path)
#      41 text_content = ''
#      43 with open(pdf_path, 'rb') as file:
# ---> 44     reader = PyPDF2.PdfFileReader(file)
#      45     for page in range(reader.numPages):
# ...

# %%
pip install pdfplumber
# Out:
# ...
#      ---------------------------------------- 54.7/54.7 kB 1.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.7/2.7 MB 7.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 5.6/5.6 MB 8.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# ...

# %%
import re
import pdfplumber
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Define the path for your PDF file and output file
pdf_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl.pdf'
output_file_path = 'output_text_file.txt'

# Initialize stemmer
stemmer = PorterStemmer()

# Function to preprocess text
def preprocess_text(text):
    # Normalize text
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation

    # Tokenize text
    tokens = word_tokenize(text)

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]

    # Stemming
    stemmed_tokens = [stemmer.stem(word) for word in filtered_tokens]

    return ' '.join(stemmed_tokens)

# Read the PDF file using pdfplumber
def extract_text_from_pdf(pdf_path):
    text_content = []
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text_content.append(page.extract_text())

    return ' '.join(text_content).replace('\n', '')

# Extract text from PDF
pdf_text = extract_text_from_pdf(pdf_file_path)

# Preprocess text
preprocessed_text = preprocess_text(pdf_text)

# Write the preprocessed text to a new file
with open(output_file_path, 'w', encoding='utf-8') as output_file:
    output_file.write(preprocessed_text)

print("Preprocessing complete. Output saved to", output_file_path)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Preprocessing complete. Output saved to output_text_file.txt

# %%
pip install pyspellchecker
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)

# %%
import re
import pdfplumber
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from spellchecker import SpellChecker

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Define the path for your PDF file and output file
pdf_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl.pdf'
output_file_path = 'output_text_file.txt'

# Initialize stemmer and spell checker
stemmer = PorterStemmer()
spell = SpellChecker()

# Function to preprocess text
def preprocess_text(text):
    # Normalize text
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'(?<!\w)([A-Za-z])\s+', r'\1', text)  # Remove space after a single letter (e.g., "A. Frank" becomes "A.Frank")
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation

    # Tokenize text
    tokens = word_tokenize(text)

    # Correct spelling
    corrected_tokens = [spell.correction(token) for token in tokens]

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in corrected_tokens if word not in stop_words]

    # Stemming
    stemmed_tokens = [stemmer.stem(word) for word in filtered_tokens]

    return ' '.join(stemmed_tokens)

# Read the PDF file using pdfplumber
def extract_text_from_pdf(pdf_path):
    text_content = []
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text_content.append(page.extract_text())

    return ' '.join(text_content).replace('\n', ' ')

# Extract text from PDF
pdf_text = extract_text_from_pdf(pdf_file_path)

# Preprocess text
preprocessed_text = preprocess_text(pdf_text)

# Write the preprocessed text to a new file
with open(output_file_path, 'w', encoding='utf-8') as output_file:
    output_file.write(preprocessed_text)

print("Preprocessing complete. Output saved to", output_file_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 7
#       5 from nltk.stem import PorterStemmer
#       6 from nltk.tokenize import word_tokenize
# ----> 7 from spellchecker import SpellChecker
#       9 # Download required NLTK data
#      10 nltk.download('punkt')
#
# File D:\Anaconda\lib\site-packages\spellchecker\__init__.py:2
#       1 # -*- coding: utf-8 -*-
# ----> 2 from  spellchecker.core import Spellchecker,getInstance
#
# File D:\Anaconda\lib\site-packages\spellchecker\core.py:26
#      23 import inexactsearch
#      24 import urllib
# ---> 26 from indexer import DictionaryIndex
#      27 from langdetect import _detect_lang
#      29 __all__ = ['Spellchecker', 'getInstance']
#
# ModuleNotFoundError: No module named 'indexer'

# %%
pip uninstall pyspellchecker
pip install pyspellchecker
# Out:
#   Cell In[7], line 1
#     pip uninstall pyspellchecker
#         ^
# SyntaxError: invalid syntax

# %%
conda install -c conda-forge pyspellchecker

# %%
import re
import pdfplumber
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# Attempt to import SpellChecker
try:
    from spellchecker import SpellChecker
except ModuleNotFoundError:
    print("SpellChecker module not found. Installing pyspellchecker...")
    import sys
    # !{sys.executable} -m pip install pyspellchecker
    from spellchecker import SpellChecker

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Define the path for your PDF file and output file
pdf_file_path = r'C:\Users\DELL\Desktop\Project\Untitled Folder\Anne-Frank-The-Diary-Of-A-Young-Girl.pdf'
output_file_path = 'output_text_file.txt'

# Initialize stemmer and spell checker
stemmer = PorterStemmer()
spell = SpellChecker()

# Function to preprocess text
def preprocess_text(text):
    # Normalize text
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'(?<!\w)([A-Za-z])\s+', r'\1', text)  # Remove space after a single letter (e.g., "A. Frank" becomes "A.Frank")
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation

    # Tokenize text
    tokens = word_tokenize(text)

    # Correct spelling
    corrected_tokens = [spell.correction(token) for token in tokens]

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in corrected_tokens if word not in stop_words]

    # Stemming
    stemmed_tokens = [stemmer.stem(word) for word in filtered_tokens]

    return ' '.join(stemmed_tokens)

# Read the PDF file using pdfplumber
def extract_text_from_pdf(pdf_path):
    text_content = []
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text_content.append(page.extract_text())

    return ' '.join(text_content).replace('\n', ' ')

# Extract text from PDF
pdf_text = extract_text_from_pdf(pdf_file_path)

# Preprocess text
preprocessed_text = preprocess_text(pdf_text)

# Write the preprocessed text to a new file
with open(output_file_path, 'w', encoding='utf-8') as output_file:
    output_file.write(preprocessed_text)

print("Preprocessing complete. Output saved to", output_file_path)
